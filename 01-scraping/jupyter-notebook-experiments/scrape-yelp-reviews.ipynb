# %%
import os
import json
import requests

# %%
api_key = os.getenv('SERPAPI_API_KEY')

params = {
    "api_key": api_key,
    "engine": "yelp_reviews",
    "place_id": "wEYj3B_EH6JS6DbfmZQudw", # example: Twenty Seven Steps, Christchurch, New Zealand
    "sortby": "date_desc"
}

# %%
search = requests.get("https://serpapi.com/search", params=params)
data = search.json()

# %%
# Pretty-print first 2 reviews for checking
for review in data.get("reviews", [])[:2]:
    user = review.get("user", {}).get("name")
    rating = review.get("rating")
    date = review.get("date")
    text = review.get("text") or ""
    print(f"{user} rated {rating}⭐ on {date}")
    print(text[:200])
    print("-" * 60)
# Out:
# John B. rated 5⭐ on 2025-03-27T05:04:34Z
#
# ------------------------------------------------------------
# Azure G. rated 5⭐ on 2025-02-14T04:09:56Z
#
# ------------------------------------------------------------

# %%
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "search_metadata": {
#     "id": "69127836556ce392e0941c60",
#     "status": "Success",
#     "json_endpoint": "https://serpapi.com/searches/9caa040754988d63/69127836556ce392e0941c60.json",
#     "created_at": "2025-11-10 23:41:42 UTC",
#     "processed_at": "2025-11-10 23:41:42 UTC",
#     "yelp_reviews_url": "https://www.yelp.com/biz/wEYj3B_EH6JS6DbfmZQudw?sort_by=date_desc",
#     "raw_html_file": "https://serpapi.com/searches/9caa040754988d63/69127836556ce392e0941c60.html",
#     "prettify_html_file": "https://serpapi.com/searches/9caa040754988d63/69127836556ce392e0941c60.prettify",
#     "total_time_taken": 4.72
#   },
#   "search_parameters": {
#     "engine": "yelp_reviews",
#     "start": 0,
#     "num": "49",
#     "sortby": "date_desc",
#     "place_id": "wEYj3B_EH6JS6DbfmZQudw"
#   },
#   "search_information": {
#     "total_results": 46,
#     "business": "Twenty Seven Steps"
#   },
#   "review_languages": [
#     {
#       "hl": "en",
#       "count": 46
#     },
#     {
#       "hl": "fr",
#       "count": 1
#     },
#     {
#       "hl": "zh",
#       "count": 1
#     }
#   ],
#   "reviews": [
#     {
#       "position": 1,
#       "user": {
#         "name": "John B.",
#         "user_id": "MgHxF_6EDUv2d3nccfqU2g",
#         "link": "https://www.yelp.com/user_details?userid=MgHxF_6EDUv2d3nccfqU2g",
#         "address": "Falmouth, MA",
#         "friends": 0,
#         "photos": 0,
#         "reviews": 9
#       },
#       "comment": {
#         "text": "A warm greeting followed by a delicious dinner served by friendly happy servers .... What more can you want ?? I had read about their duck parfait app which to my dismay was not on the menu that night !!! A quiet inquiry and lo &behold , the duck parfait app was delicious !!! Squad leader had a tenderloin and i had rack o lamb in a delicious veg succotash. A delicious meal w/ exemplary service mere steps from Fable Christchurch Hotel. . Highly recommend",
#         "language": "en"
#       },
#       "date": "2025-03-27T05:04:34Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 2,
#       "user": {
#         "name": "Azure G.",
#         "user_id": "Z583nOzi9vc0X5O1HyW2gA",
#         "link": "https://www.yelp.com/user_details?userid=Z583nOzi9vc0X5O1HyW2gA",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/QNn_TCQujuBJHXDcugkW_g/180s.jpg",
#         "address": "Denver, CO",
#         "friends": 40,
#         "photos": 332,
#         "reviews": 474,
#         "elite_year": 25
#       },
#       "comment": {
#         "text": "Twenty Seven Steps - what a spot! Intimate space in a lovely location with great service, expansive wine selection and they are happy to make you a tasty mocktail that suits your palate. \n\nNow... the food. Epic. Seasonal. Simple. Divine. I started with their marinated tomato salad which was fresh and flavorful. Entree was the steak with potato, onion rings and veggies - absolutely incredible. Naturally I had to save room for dessert and landed on the vanilla crème brûlée (though all the options sounded amazing). It came with fresh fruit and pistachio biscotti and was a great way to round out the meal. \n\nI would come back here again and again and again. Bravo!!",
#         "language": "en"
#       },
#       "date": "2025-02-14T04:09:56Z",
#       "rating": 5,
#       "tags": [
#         "1 photo"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/33kTtS2MY9IO-Fyn4qMWdA/o.jpg",
#           "caption": "Steak"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 3,
#       "user": {
#         "name": "Calista C.",
#         "user_id": "PqR0KB_K7KBVtacEBJTqjg",
#         "link": "https://www.yelp.com/user_details?userid=PqR0KB_K7KBVtacEBJTqjg",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/iv4bf65Xa5WD738X70W6sw/180s.jpg",
#         "address": "Irvine, CA",
#         "friends": 20,
#         "photos": 117,
#         "reviews": 147,
#         "elite_year": 25
#       },
#       "comment": {
#         "text": "Visited here while on my stop in Christchurch. Easily the best meal I had in town. They're on the second floor, above their sister restaurant, Downstairs. Upon being seated, the server was extremely thorough going over the menu and offered excellent recommendations. I got the duck liver pate and their lamb. Both were incredible, especially the duck liver pate. Will definitely be back if I'm in town again",
#         "language": "en"
#       },
#       "date": "2025-01-29T21:31:56Z",
#       "rating": 5,
#       "tags": [
#         "1 photo"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/stxi4U4SiLwWZ2a_cqUlMA/o.jpg",
#           "caption": "Lamb"
#         }
#       ],
#       "feedback": {
#         "useful": 2,
#         "funny": 0,
#         "cool": 2
#       }
#     },
#     {
#       "position": 4,
#       "user": {
#         "name": "Jasper R.",
#         "user_id": "IaX6kVl4TCH5U0lhfSvRMw",
#         "link": "https://www.yelp.com/user_details?userid=IaX6kVl4TCH5U0lhfSvRMw",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/pfzZKjGtImYOkDASID5miw/180s.jpg",
#         "address": "Lathrop, CA",
#         "friends": 0,
#         "photos": 9,
#         "reviews": 8
#       },
#       "comment": {
#         "text": "Everything in here was amazing! One of my favorite places!\n\nThe service is top-notch. They are so attentive and flexible depending on the needs of the table. \nThe food is always on point and priced reasonably.\nCute 2nd story location, in a bit of a smaller space but the tables are spaced appropriately and comfortably away from other guests.\n\nMake sure to make reservations as they do get quite busy.",
#         "language": "en"
#       },
#       "date": "2024-11-20T04:47:31Z",
#       "rating": 5,
#       "tags": [
#         "4 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/wlpUaZaa8n2BCowRNmnVLQ/o.jpg",
#           "caption": "Pistachio encrusted Lamb Chops"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/7E0otTriEjfylc81tilufg/o.jpg",
#           "caption": "Banana Split"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/g_yMhqkgpotGWVDIotooHQ/o.jpg",
#           "caption": "Angus Beef Fillet"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/4Gwkvo9q86k1BNjsG7-99Q/o.jpg",
#           "caption": "Tomato basil soup and slow braised pork belly."
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 5,
#       "user": {
#         "name": "Andy M.",
#         "user_id": "ODxAjIjfWnQ7wFttrNlE7A",
#         "link": "https://www.yelp.com/user_details?userid=ODxAjIjfWnQ7wFttrNlE7A",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/-BYpKX8xKyyDvnzgE0PvZg/180s.jpg",
#         "address": "Cincinnati, OH",
#         "friends": 1,
#         "photos": 169,
#         "reviews": 234
#       },
#       "comment": {
#         "text": "Cool atmosphere, great service, and the good food. The soup and monkfish was delicious!",
#         "language": "en"
#       },
#       "date": "2024-10-25T05:19:39Z",
#       "rating": 4,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 6,
#       "user": {
#         "name": "Kelvin M.",
#         "user_id": "BAu0ZsiaXwhlLSvdVP7IBg",
#         "link": "https://www.yelp.com/user_details?userid=BAu0ZsiaXwhlLSvdVP7IBg",
#         "address": "Buenos Aires, Argentina",
#         "friends": 0,
#         "photos": 0,
#         "reviews": 2
#       },
#       "comment": {
#         "text": "Everything really.  Staff very friendly but that venison meal was just superb \nI am booking real early next time to make I can get a table \n:)",
#         "language": "en"
#       },
#       "date": "2024-07-21T06:25:26Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 7,
#       "user": {
#         "name": "Abby H.",
#         "user_id": "cowAGc5BveAlFwLqaafnBA",
#         "link": "https://www.yelp.com/user_details?userid=cowAGc5BveAlFwLqaafnBA",
#         "address": "San Francisco Bay Area, CA",
#         "friends": 0,
#         "photos": 10,
#         "reviews": 3
#       },
#       "comment": {
#         "text": "really wonderful restaurant and wine bar. they have a changing menu that has very unique creations. staff is super friendly and welcoming. sadly i don't live near here, otherwise i would've been here all the time!",
#         "language": "en"
#       },
#       "date": "2024-05-15T09:22:11Z",
#       "rating": 5,
#       "tags": [
#         "3 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/ArS2_ZEp71WYvE4VBK-YFQ/o.jpg",
#           "caption": "dessert"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/SE0WnYWeWnVwlJT7ooGcyQ/o.jpg"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/mTu6N9ZIirvbV8I0ufQNlg/o.jpg",
#           "caption": "beet risotto"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 8,
#       "user": {
#         "name": "友美",
#         "user_id": "gkSyczctW9VQOlJ7xeQpYQ",
#         "link": "https://www.yelp.com/user_details?userid=gkSyczctW9VQOlJ7xeQpYQ",
#         "address": "Auckland, New Zealand",
#         "friends": 0,
#         "photos": 3,
#         "reviews": 2
#       },
#       "comment": {
#         "text": "It's a pretty fully booked place and it's almost impossible to get in without a booking. Luckily enough, the sister restaurant downstairs allowed us to sit down but still order from upstairs. \nThe food is okay I guess. I was way too hyped about it so it was a bit let down that the food didn't live up to my hype. It wasn't the restaurants fault. The service is really good. Food wise, it's not bad at all but I wouldn't necessarily come back again cos it's just fine. But not like Wow kinda food.",
#         "language": "en"
#       },
#       "date": "2024-04-12T06:52:26Z",
#       "rating": 4,
#       "tags": [
#         "1 photo"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/EZmsrV_S4WKJajTKTL71fA/o.jpg"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 9,
#       "user": {
#         "name": "Sara Jo L.",
#         "user_id": "a6ckC4sHF4X3hcSzEqegXQ",
#         "link": "https://www.yelp.com/user_details?userid=a6ckC4sHF4X3hcSzEqegXQ",
#         "address": "Parker, CO",
#         "friends": 0,
#         "photos": 2,
#         "reviews": 50
#       },
#       "comment": {
#         "text": "Grilled peach salad was exceptional only to be topped by the Monkfish. Excellent sauces, exquisite mix of veggies & greens. The dark chocolate hazelnut tort -  delicious. Lovely setting & excellent service. Highly recommend.",
#         "language": "en"
#       },
#       "date": "2024-04-06T05:38:35Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 10,
#       "user": {
#         "name": "Winnie Y.",
#         "user_id": "Z9aLttY7x43Xw6n0n-3sBw",
#         "link": "https://www.yelp.com/user_details?userid=Z9aLttY7x43Xw6n0n-3sBw",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/-8hwNIcszgbt_jLmst1HEg/180s.jpg",
#         "address": "Castro Valley, CA",
#         "friends": 39,
#         "photos": 606,
#         "reviews": 671,
#         "elite_year": 25
#       },
#       "comment": {
#         "text": "Don't get this place confused with the sister restaurant downstairs. Twenty Seven Steps is upstairs (and ONLY upstairs). Tiny place so reservations are highly recommended. I wasn't able to make one but they were able to squeeze me in (party of one) if I finished in less than an hour which I did. Seating is a little cramped in some areas but I appreciate them for trying to accommodate as may guests as they can. Food is fantastic and high quality and pricing is fair. Portions are adequate and I was stuffed. Service is standard.",
#         "language": "en"
#       },
#       "date": "2023-12-22T00:21:34Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 11,
#       "user": {
#         "name": "Kevin K.",
#         "user_id": "6Q2wjEVWjHXHvR0SX6_Gjg",
#         "link": "https://www.yelp.com/user_details?userid=6Q2wjEVWjHXHvR0SX6_Gjg",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/W3H7p957Mz4PN9QqTu34Dg/180s.jpg",
#         "address": "Reno, NV",
#         "friends": 114,
#         "photos": 4,
#         "reviews": 2
#       },
#       "comment": {
#         "text": "Very tasty. Great service. Nice environment.   \n \nStrong recommended!\n\nToo many characters need to do.",
#         "language": "en"
#       },
#       "date": "2023-12-04T07:35:16Z",
#       "rating": 5,
#       "tags": [
#         "2 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/ac8g-gvLTsbTuQPD4ZotWw/o.jpg",
#           "caption": "Deer"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/y9RjLjgsZ__52TM70twuAg/o.jpg",
#           "caption": "Soup of the day"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 12,
#       "user": {
#         "name": "Ruth M.",
#         "user_id": "yNnb94PYU5mPEmEBihkDCA",
#         "link": "https://www.yelp.com/user_details?userid=yNnb94PYU5mPEmEBihkDCA",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/1IJmdF39Bnn5FunS776vUQ/180s.jpg",
#         "address": "Christchurch, New Zealand",
#         "friends": 0,
#         "photos": 0,
#         "reviews": 9
#       },
#       "comment": {
#         "text": "This darling little restaurant serves fantastic food and very good wine. Reservations are a must! The vegetarian offerings are always excellent, which I appreciate.",
#         "language": "en"
#       },
#       "date": "2023-10-09T09:42:07Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 13,
#       "user": {
#         "name": "Joseph G.",
#         "user_id": "jT3ZyI_kuc_4cwiLA2gVsA",
#         "link": "https://www.yelp.com/user_details?userid=jT3ZyI_kuc_4cwiLA2gVsA",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/10_yN_HgBmia4nfHOgzpCg/180s.jpg",
#         "address": "Orlando, FL",
#         "friends": 39,
#         "photos": 6,
#         "reviews": 9
#       },
#       "comment": {
#         "text": "Have to thank ChatGTP for the recommendation. What a cute little restaurant with fantastic food. Definitely make a reservation as this place gets busy.",
#         "language": "en"
#       },
#       "date": "2023-02-25T06:12:32Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 14,
#       "user": {
#         "name": "Ken E.",
#         "user_id": "unMgZ_UBfvoe-_sO0GzLKw",
#         "link": "https://www.yelp.com/user_details?userid=unMgZ_UBfvoe-_sO0GzLKw",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/4LRRn6pWvYkMVqVoBZ1nmA/180s.jpg",
#         "address": "Amsterdam, The Netherlands",
#         "friends": 0,
#         "photos": 2,
#         "reviews": 9
#       },
#       "comment": {
#         "text": "Excellent dinner. You go upstairs to the restaurant which was a wee bit of a surprise as downstairs is merely a waiting area. Stater we had a superb \"special\" duck pate and fir main I had a wonderful fresh pea risotto, my partner loved the lamb rack. Sticky dare pudding was easily big enough to share and yummy too. Will be back for sure.",
#         "language": "en"
#       },
#       "date": "2020-10-03T19:08:04Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 15,
#       "user": {
#         "name": "Peter P.",
#         "user_id": "ZGm3kqcOxCqb_-Oop_esig",
#         "link": "https://www.yelp.com/user_details?userid=ZGm3kqcOxCqb_-Oop_esig",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/SqermNQPQcoPpkHRj8Cy3Q/180s.jpg",
#         "address": "Auckland, New Zealand",
#         "friends": 0,
#         "photos": 23,
#         "reviews": 15
#       },
#       "comment": {
#         "text": "Great place hidden upstairs from Main Street of New Regent St. wonderful food and great ambience. Well worth the visit.",
#         "language": "en"
#       },
#       "date": "2020-07-24T09:46:51Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 16,
#       "user": {
#         "name": "Nancy D.",
#         "user_id": "EDNCpOadxZjCT391tJwmFA",
#         "link": "https://www.yelp.com/user_details?userid=EDNCpOadxZjCT391tJwmFA",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/xS6Ny5g0-_qtLBvyZteO9Q/180s.jpg",
#         "address": "Lutz, FL",
#         "friends": 0,
#         "photos": 0,
#         "reviews": 19
#       },
#       "comment": {
#         "text": "This restaurant and the food was amazing. I highly recommend it. Our waiter was Dean and he was extremely attentive and made great food recommendations. This was our best dinner in New Zealand.",
#         "language": "en"
#       },
#       "date": "2020-03-03T04:19:32Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 17,
#       "user": {
#         "name": "Steve M.",
#         "user_id": "9fYHxaFFyTl3r2fDIQEUaQ",
#         "link": "https://www.yelp.com/user_details?userid=9fYHxaFFyTl3r2fDIQEUaQ",
#         "address": "Stafford, VA",
#         "friends": 0,
#         "photos": 3,
#         "reviews": 58
#       },
#       "comment": {
#         "text": "This restaurant will not disappoint you. Before going I searched Yelp and found Twenty Seven Steps with super ratings/reviews. The appearance of the restaurant is a bit underwhelming but that just added to its appeal. We had the mushroom risotto and grouper, their fish of the day. Both dishes were excellent and cooked to perfection. The staff was friendly and very efficient. I highly recommend this restaurant.",
#         "language": "en"
#       },
#       "date": "2020-02-27T12:20:20Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 18,
#       "user": {
#         "name": "Justin Y.",
#         "user_id": "pCUGiu2fuiFu49aKjs9icQ",
#         "link": "https://www.yelp.com/user_details?userid=pCUGiu2fuiFu49aKjs9icQ",
#         "address": "La Cañada Flintridge, CA",
#         "friends": 194,
#         "photos": 15,
#         "reviews": 56
#       },
#       "comment": {
#         "text": "Alright so I hate to be the dissenter but this place was just ok for me. The food tasted great but the portions were exceeding small. I got the lamb rack which was four pieces, each with meat about the size of a cherry tomatoe (see picture). There was a small serving of potatoes and a meatball as well with veggies. At $42, it was definitely overpriced. I have had bigger portions at about half the price for the same taste elsewhere in NZ. The service was hectic and spotty. I think they may have taken the modern European thing a bit too far.",
#         "language": "en"
#       },
#       "date": "2020-02-16T19:19:25Z",
#       "rating": 2,
#       "tags": [
#         "1 photo"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/js1O-z0-EvzefG6QUPzK_w/o.jpg",
#           "caption": "The meat is the same size as the Cherry Tomato."
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 19,
#       "user": {
#         "name": "Yubo Z.",
#         "user_id": "kjSISRREAulrAsT_ayk-2Q",
#         "link": "https://www.yelp.com/user_details?userid=kjSISRREAulrAsT_ayk-2Q",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/Aj0M28Gs2dMbqXU2UjfEgw/180s.jpg",
#         "address": "San Mateo, CA",
#         "friends": 66,
#         "photos": 24,
#         "reviews": 17
#       },
#       "comment": {
#         "text": "Lamb kidney surprised us the most. Rich flavor, well combined, please order one if you feel like trying something new today. Beef fillet is above average. Overall the food was good, but seatings are all very close to each other. You can easily get bumped by people walking by.",
#         "language": "en"
#       },
#       "date": "2019-12-18T05:38:52Z",
#       "rating": 5,
#       "tags": [
#         "3 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/6qedQ8WUC8Kc57VgvOgqHA/o.jpg",
#           "caption": "Beef fillet with potatoes fried with duck fat"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/27_OwIpAWamg4-ZqUC7f0A/o.jpg",
#           "caption": "Soup of the day - chowder like, with a hint of apples cider"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/f_NuNnZD7p1DyDakhLVTEA/o.jpg",
#           "caption": "Lamb kidney"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 20,
#       "user": {
#         "name": "Nicolas L.",
#         "user_id": "4e9-roUfqfa7fp3zdMKDvw",
#         "link": "https://www.yelp.com/user_details?userid=4e9-roUfqfa7fp3zdMKDvw",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/W1hBgbKsTKAHLU3QTTJxwQ/180s.jpg",
#         "address": "Lakeland, FL",
#         "friends": 90,
#         "photos": 2363,
#         "reviews": 923,
#         "elite_year": 25
#       },
#       "comment": {
#         "text": "My wife and I recently had a nice dinner at Twenty Seven Steps. During our visit I ordered the White Onion, Cider & Apple Soup, the Roast Canterbury Lamb Rack, and the Black Forest & Dark Chocolate Delice. The soup was rich, flavorful, and lightly sweet. The lamb was juicy and tender and paired with a seasoned meatball, savory mashed potatoes, and tender veggies. The chocolate delice featured rich chocolate, fresh juicy strawberries and cherries, and creamy ice cream. Overall, Twenty Seven Steps is a quality spot for a nice dinner.",
#         "language": "en"
#       },
#       "date": "2019-11-04T21:43:39Z",
#       "rating": 4,
#       "tags": [
#         "3 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/rM_5BjvjbZ4nNwiSVampQw/o.jpg",
#           "caption": "Black Forest & Dark Chocolate Delice"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/30eda6yJDvFJaOqLstWUXw/o.jpg",
#           "caption": "White Onion, Cider & Apple Soup"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/6IGZF0sChKWpnYlEcFDQwg/o.jpg",
#           "caption": "Roast Canterbury Lamb Rack"
#         }
#       ],
#       "feedback": {
#         "useful": 4,
#         "funny": 2,
#         "cool": 4
#       }
#     },
#     {
#       "position": 21,
#       "user": {
#         "name": "Debra O.",
#         "user_id": "dZpLwqrcU4ywjrrvJTaohQ",
#         "link": "https://www.yelp.com/user_details?userid=dZpLwqrcU4ywjrrvJTaohQ",
#         "address": "Rowlett, TX",
#         "friends": 1,
#         "photos": 0,
#         "reviews": 16
#       },
#       "comment": {
#         "text": "This was a real treat during my visit to New Zealand and Christchurch in particular.  Delicious and unique flavors.  Wait staff very helpful and friendly.",
#         "language": "en"
#       },
#       "date": "2019-10-17T16:43:33Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 22,
#       "user": {
#         "name": "Nickie A.",
#         "user_id": "C-PRPOAjVrUk7Li9fdqqgg",
#         "link": "https://www.yelp.com/user_details?userid=C-PRPOAjVrUk7Li9fdqqgg",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/lLYVcVTN-FFf8tDHIiBQFg/180s.jpg",
#         "address": "Whitacre, VA",
#         "friends": 6,
#         "photos": 5,
#         "reviews": 20
#       },
#       "comment": {
#         "text": "Our daughter made this reservation for us while visiting New Zealand and we are so happy she did!  It's not easy to find, but oh so worth it.  My husband had the Venison and I had the Lamb.  Both were cooked to perfection.  Our wine from the region was perfect, too.  Service was amazing too.  If you visit Christchurch, New Zealand, you must eat here, however, make sure you make reservations, since it's always full.",
#         "language": "en"
#       },
#       "date": "2019-10-01T21:08:34Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 2,
#         "funny": 0,
#         "cool": 2
#       }
#     },
#     {
#       "position": 23,
#       "user": {
#         "name": "Bradley R.",
#         "user_id": "Y0Cu8jBJsdpwqRQReLx35Q",
#         "link": "https://www.yelp.com/user_details?userid=Y0Cu8jBJsdpwqRQReLx35Q",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/MNJxIACdQLix14ycqCcTWg/180s.jpg",
#         "address": "Pasadena, TX",
#         "friends": 21,
#         "photos": 57,
#         "reviews": 433
#       },
#       "comment": {
#         "text": "Sometimes I am completely surprised by how good restaurant is when it looks more like a bistro - this was one of those times. During our visit to Christchurch we found several interesting places to eat and wanted to make our last night special by choosing this locally well rated restaurant. \n\nAs the name suggests, you enter by climbing 27 steps to find a very small space with minimalist furnishings of very simple tables and chairs. A small complete bar is to your right as you enter - we were quickly seated at a postage stamp sized table. The menu is basically what the chef fancies to prepare for dinner - so on-line menus just list items that are basic rather than recommended for each evening. I enjoy one of the best prepared filet Mignons I have eaten in a long time and shared some of my wife's risotto and a house made bread to make a wonderful tasting meal! Although they were very busy, our server took her time with us to ensure we got the best of what they had to offer - including a very tasty Pinot Noir fro the region. \n\nHighly recommend and will be back!",
#         "language": "en"
#       },
#       "date": "2019-08-25T01:59:43Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 1
#       }
#     },
#     {
#       "position": 24,
#       "user": {
#         "name": "Richard S.",
#         "user_id": "BvinRSbBlgNQRd1ZXFSOkg",
#         "link": "https://www.yelp.com/user_details?userid=BvinRSbBlgNQRd1ZXFSOkg",
#         "address": "Portland, OR",
#         "friends": 0,
#         "photos": 0,
#         "reviews": 140
#       },
#       "comment": {
#         "text": "Very popular and thus crowded Christchurch bistro, upstairs (27 steps--get it?) from the pedestrian restaurant street. Good but not memorable food. The usual friendly and sincere New Zealand service. It was an enjoyable dinner.",
#         "language": "en"
#       },
#       "date": "2019-08-01T03:34:04Z",
#       "rating": 4,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 25,
#       "user": {
#         "name": "Siobhan E.",
#         "user_id": "7AH_Mja2lPWDstswzqjdGg",
#         "link": "https://www.yelp.com/user_details?userid=7AH_Mja2lPWDstswzqjdGg",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/XT0NaP0AOeLSB8mDUbSYAA/180s.jpg",
#         "address": "Darwin, Australia",
#         "friends": 33,
#         "photos": 139,
#         "reviews": 44
#       },
#       "comment": {
#         "text": "Delicious food and lovely atmosphere upstairs on New Regent St. However, the waitress we had tonight was very abrupt and did not seem very genuine at all. I know it can be tiring working in hospitality but we did not feel like valued customers even though we were paying the $$$ prices. We were hurried through our entree and main, and the request of dessert was hurried. We said no to dessert as we weren't ready, and the bill immediately came to the table. We hadn't finished our drinks and felt like we were just being pushed out the door. We had a reservation by the way, 6pm, Sunday night. Hardly a peak busy night where they are trying to turn people through quickly. Otherwise service was prompt and \"polite\" enough. But not warm or inviting. \nAnyway - if you've made it this far - the food was so lovely! I had pan seared scollops with pork belly and a perfectly cooked beef fillet with potato gratin. \n4 stars because of the waitress's attitude.",
#         "language": "en"
#       },
#       "date": "2019-07-21T10:01:00Z",
#       "rating": 4,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 26,
#       "user": {
#         "name": "Ali H.",
#         "user_id": "zqeOwIpO1a2IUXkU8s1oyg",
#         "link": "https://www.yelp.com/user_details?userid=zqeOwIpO1a2IUXkU8s1oyg",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/jVMyPHV1GwkXoKg9YWgckw/180s.jpg",
#         "address": "Wellington, New Zealand",
#         "friends": 0,
#         "photos": 661,
#         "reviews": 523
#       },
#       "comment": {
#         "text": "I enjoyed a fabulous dinner with family and friends here. We booked the second sitting (7.30pm) and were seated at a very nice table. There is a blackboard menu and menus on the table, then staff make sure they explain the dishes also - this is very helpful as people receive information in different ways, a good idea. We enjoyed marvellous food - entrees were Scallops, Soup and Pork, then main courses were Angus steak, Venison and Risotto - all were served beautifully and totally divine. We were treated with friendly but professional and respectful service throughout the evening. The serving staff, particularly Natalie, were thoroughly delightful. Natalie paid particular attention to my brother, whose birthday we were there to celebrate. Thank you - I look forward to coming again.",
#         "language": "en"
#       },
#       "date": "2019-07-04T18:45:35Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 27,
#       "user": {
#         "name": "JP N.",
#         "user_id": "j71dhbsJSqN4TseEcAZqAQ",
#         "link": "https://www.yelp.com/user_details?userid=j71dhbsJSqN4TseEcAZqAQ",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/2Xd7k9qsy51rr93u3FB8jQ/180s.jpg",
#         "address": "Great Kills, Staten Island, NY",
#         "friends": 0,
#         "photos": 4,
#         "reviews": 20
#       },
#       "comment": {
#         "text": "Call. If you can't get through, email. But if you are a foodie and you're in Christchurch, EAT HERE. The food is spectacular. The chef prepares interesting, locally sourced masterpieces paired with an excellent wine list.  The two appetizers (entrees for our friends from everywhere else) we chose were a scallop special and the calamari. Both were creative, smart and delicious.  The mains were a special risotto of pears and spring onions and ricotta that tasted so much like freshness on a plate, and the venison special, which melted in our mouths.  Dessert (embarrassing, I know, that we kept eating) was a blood orange crème brûlée that we just couldn't resist. Service was attentive and fun. Decor is minimal and chic. Get here. Don't miss it.",
#         "language": "en"
#       },
#       "date": "2019-04-23T18:32:25Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 2,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 28,
#       "user": {
#         "name": "Patricia T.",
#         "user_id": "pJ9j5Nr7SMqlFLjrqJa3SQ",
#         "link": "https://www.yelp.com/user_details?userid=pJ9j5Nr7SMqlFLjrqJa3SQ",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/jD4WW4stmTb0yOHgnVTgIg/180s.jpg",
#         "address": "Dallas, TX",
#         "friends": 79,
#         "photos": 74,
#         "reviews": 178
#       },
#       "comment": {
#         "text": "We just happened upon this place during our visit, and last stop, in Christchurch. it seemed slow in dead on the first floor but we were led up to the second floor and saw how packed and lively it was! We decided to split three courses, all were exceptional. The first course we ordered were are the sautéed lamb kidneys, something neither of us have had before and it was so flavorful very tender. We have been so impressed with the meat in New Zealand so we ordered the aged Canterbury 200g beef cooked medium rare. Wow. You will taste nothing like this in the United States. Highly recommend!!!! For dessert, we ordered one of their seasonal selections which had a confit pear, ice cream, caramel popcorn, and praline. All plated so beautifully.",
#         "language": "en"
#       },
#       "date": "2019-03-24T13:55:06Z",
#       "rating": 5,
#       "tags": [
#         "4 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/dt5XalEeCqtUUinVcC073A/o.jpg"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/QHS0TVMiXhZl3-7Lq5X-IA/o.jpg",
#           "caption": "Aged Canterbury 200g beef"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/Tm4M7pyCxJC7tMn9P6-WVg/o.jpg",
#           "caption": "Seasonal dessert with confit pear, caramel popcorn, praline, and some sort of ice cream."
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/svS2wTzMw_aeuuYwrSk33Q/o.jpg"
#         }
#       ],
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 29,
#       "user": {
#         "name": "Ashley M.",
#         "user_id": "-cVFO8dmTVH2P2BdWAQoqQ",
#         "link": "https://www.yelp.com/user_details?userid=-cVFO8dmTVH2P2BdWAQoqQ",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/v0g9eK3ou8XhGZvQq-kAgw/180s.jpg",
#         "address": "CO, CO",
#         "friends": 308,
#         "photos": 6,
#         "reviews": 28
#       },
#       "comment": {
#         "text": "If you don't have a reservation, come early because they are packed (and with good reason). The food was HEAVENLY - I had the risotto of the day and will dream about it for years to come. The scallops were phenomenal and juicy, I would highly recommend them. The salmon pâté was also delicious. Overall, one of the best meals I've ever had.",
#         "language": "en"
#       },
#       "date": "2019-03-22T22:26:10Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 30,
#       "user": {
#         "name": "John W.",
#         "user_id": "Mf9iQIeX07DkFWqPMUf2rw",
#         "link": "https://www.yelp.com/user_details?userid=Mf9iQIeX07DkFWqPMUf2rw",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/YwjKLboD30dKUXqjka2_cQ/180s.jpg",
#         "address": "Leeston, New Zealand",
#         "friends": 0,
#         "photos": 0,
#         "reviews": 1
#       },
#       "comment": {
#         "text": "Recommend reservations if you want to attend here. I would give it 6 out of five. The food is sublime and both meals we ordered was as fresh as could be and melted in the mouth. The before dinner bread was so perfectly soft it was like cake. Very nice asthetic to this place and yes its romantic. Meals are higher priced around $40 dollars but you see where the money goes in the quality. Very popular.",
#         "language": "en"
#       },
#       "date": "2019-03-11T19:59:23Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 31,
#       "user": {
#         "name": "David M.",
#         "user_id": "YdKP_3uhYRci_6WgUw_uUQ",
#         "link": "https://www.yelp.com/user_details?userid=YdKP_3uhYRci_6WgUw_uUQ",
#         "address": "Danville, CA",
#         "friends": 0,
#         "photos": 0,
#         "reviews": 4
#       },
#       "comment": {
#         "text": "The meals were superb and they were extremely flexible and accommodating with our dietary needs.The staff was very freindly and professional and service was excellent. I would highly recommend this restaurant.",
#         "language": "en"
#       },
#       "date": "2019-03-04T07:26:45Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 32,
#       "user": {
#         "name": "Gordon W.",
#         "user_id": "OdkQnExgrEi2n6wbkn6lvQ",
#         "link": "https://www.yelp.com/user_details?userid=OdkQnExgrEi2n6wbkn6lvQ",
#         "address": "Walnut Creek, CA",
#         "friends": 0,
#         "photos": 12,
#         "reviews": 66
#       },
#       "comment": {
#         "text": "This restaurant is great for vegetarians too!  We started with a salad.  Had the risotto and a plate with a whole slow roasted beet, smoked shredded potato, cashew cream and greens.  It was magnificent and tasted so much better than it reads.  Menu changes based on freshest available.  I would trust them to always create something fantastic.  Great selection of wines by the glass with knowledgeable servers.  Service and atmosphere are relaxed, comfortable and professional.  I would go back right now for the same dishes.",
#         "language": "en"
#       },
#       "date": "2019-03-02T02:58:18Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 33,
#       "user": {
#         "name": "Jeff R.",
#         "user_id": "ppKKM7ppbypN-vjZyfQJ6A",
#         "link": "https://www.yelp.com/user_details?userid=ppKKM7ppbypN-vjZyfQJ6A",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/gdgmJIpidFgzWUbGy_RU5g/180s.jpg",
#         "address": "Bremerton, WA",
#         "friends": 33,
#         "photos": 0,
#         "reviews": 28
#       },
#       "comment": {
#         "text": "Our whole party of 4. Thoroughly enjoyed our meal. Risotto, lamb x2, fish. Topped it off with a bottle of wine from Hawkes Hill.",
#         "language": "en"
#       },
#       "date": "2018-10-30T07:29:12Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 34,
#       "user": {
#         "name": "Heather P.",
#         "user_id": "khMy2utlvRq3nY5oAe0reg",
#         "link": "https://www.yelp.com/user_details?userid=khMy2utlvRq3nY5oAe0reg",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/SMlpH8UO0IE4eg2zhPZ6Ag/180s.jpg",
#         "address": "Hanover, MD",
#         "friends": 47,
#         "photos": 343,
#         "reviews": 143
#       },
#       "comment": {
#         "text": "We had one meal in Christchurch before leaving the next morning for home and I'm so glad we chose 27 Steps. We walked in at the opening time of 5pm as we didn't have reservations and for the entire hour we were there a handful of tables were seated during that time; Pro Tip: have an early dinner! We had the scallop and chorizo app, 300g rib eye special, and a couple cocktails. The star of the show was the Rib Eye with duck fat and horseradish cream; I have lived in the Midwest US for the past 5 years and I thought it was in definite competition with steak I have had in the meat Mecca, which is saying a lot. Sadly we didn't stay for dessert but they had several that I considered, get one so I can live vicariously thru you.",
#         "language": "en"
#       },
#       "date": "2018-09-24T08:35:20Z",
#       "rating": 5,
#       "tags": [
#         "3 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/r0tOeBMs1Vh8QLuuvMFfwg/o.jpg",
#           "caption": "Foxy Lady and Cry Baby"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/D5IAOi6dDAvujy3zTUu0BQ/o.jpg",
#           "caption": "Menu of the day, get the ribeye!"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/rnT50AmHfJRi7VfVKAhbBQ/o.jpg",
#           "caption": "300kg ribeye with bone marrow horseradish sauce, scallops and chorizo app"
#         }
#       ],
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 35,
#       "user": {
#         "name": "Erika R.",
#         "user_id": "2XQJKxAwMLXoiGqfol8M_Q",
#         "link": "https://www.yelp.com/user_details?userid=2XQJKxAwMLXoiGqfol8M_Q",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/eXQxcHw7x6Jz-Po-Dqe1Lg/180s.jpg",
#         "address": "Ventura, CA",
#         "friends": 141,
#         "photos": 668,
#         "reviews": 163
#       },
#       "comment": {
#         "text": "We made reservation for Friday night for 3. Depsite the place being pretty busy, service was great.  They start you off with wonderfully fresh sourdough pumpkin hummus bread.  They also had a pretty extensive wine list with delicious selections!\n\nThe most delicious part of our meal was the chargrilled chicory, cauliflower, dates with a coconut yogurt (tasted like lemon ricotta cheese) and organic greens.  \n\nWe also had the soup or the day - which was yam with spinach and buttermilk topped with amazing pesto. Delicious and warm - perfect for a cold night. We alsohad the special appetizer of the day - scallops with chorizo. The scallops were a tad small - but I always feel like restaurants overcharge for scallops - so this was somewhat to be expected. We finished off with the beef fillet with vegetables, potato and Yorkshire pudding.  The beef fillet was cooked perfectly and since we got the leaner cut of meat, they added camembert cheese - yum!",
#         "language": "en"
#       },
#       "date": "2018-09-21T10:40:19Z",
#       "rating": 5,
#       "tags": [
#         "4 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/BQxF8J0MNde8_AhePdBqUw/o.jpg"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/p3lj7WArRSFflbM-O0jnIQ/o.jpg"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/PvTd-qlLcqG6vLh350qfYA/o.jpg"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/rCNhkTNdOQtTy4u58farvw/o.jpg"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 36,
#       "user": {
#         "name": "Cindy C.",
#         "user_id": "wJO3aNkWWauw8berbCfOOg",
#         "link": "https://www.yelp.com/user_details?userid=wJO3aNkWWauw8berbCfOOg",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/V0w3ll8yiX01CoCNg-OpGw/180s.jpg",
#         "address": "Bellevue, WA",
#         "friends": 338,
#         "photos": 28,
#         "reviews": 97
#       },
#       "comment": {
#         "text": "Nice atmosphere and recommendation for the Pinot Noir. Servers were very friendly and the lamb was delicious.\nCame on a Tuesday night at 6pm and it was nearly empty. Highly recommend if you want to have a nice, quiet weekday dinner at a good local restaurant.",
#         "language": "en"
#       },
#       "date": "2018-08-14T23:14:28Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 37,
#       "user": {
#         "name": "Navaz K.",
#         "user_id": "rUGa7-hPyA39925IyICVJw",
#         "link": "https://www.yelp.com/user_details?userid=rUGa7-hPyA39925IyICVJw",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/V69YRO1B6EAPytaD2dNnkw/180s.jpg",
#         "address": "La Jolla, CA",
#         "friends": 76,
#         "photos": 4,
#         "reviews": 53
#       },
#       "comment": {
#         "text": "Had a fantastic meal here. I got the lamb and hubby got the steak--all were delicious and paired wonderfully with wine by our server. Service was also fantastic, friendly, and very knowledgeable about the food, wine, and the general area. Would definitely go back if in the area again!",
#         "language": "en"
#       },
#       "date": "2018-05-25T09:41:47Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 38,
#       "user": {
#         "name": "Christine D.",
#         "user_id": "EhR6IzTrSyKUQDuHMkfakA",
#         "link": "https://www.yelp.com/user_details?userid=EhR6IzTrSyKUQDuHMkfakA",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/hATtOQ1qgGEAQ3ywAe2PEQ/180s.jpg",
#         "address": "Crockett, CA",
#         "friends": 121,
#         "photos": 137,
#         "reviews": 315
#       },
#       "comment": {
#         "text": "We dined here on our first evening in Christchurch. Reservations are recommended. The restaurant is located upstairs. There is a bar on the lower level as well as a small one upstairs. They serve fresh homemade bread! Your first serving is complementary with your meal order. Otherwise you are charged for second helpings. The food was fresh and delicious. The specials are wonderful. Everything from the starters all the way to the dessert was superb! If we come to NZ again we will definitely come back!\n\nGreat Date place!",
#         "language": "en"
#       },
#       "date": "2018-03-27T00:04:57Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 39,
#       "user": {
#         "name": "Jeannette N.",
#         "user_id": "Xp0gC-xpP7iEKTNXCM6WZw",
#         "link": "https://www.yelp.com/user_details?userid=Xp0gC-xpP7iEKTNXCM6WZw",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/PmOyOhDGIiBRXUqktuc9Ug/180s.jpg",
#         "address": "Brooklyn, NY",
#         "friends": 240,
#         "photos": 1995,
#         "reviews": 270
#       },
#       "comment": {
#         "text": "I was lucky to get a table when I walked in around 5:45pm. The restaurant wasn't too busy then but within 15 minutes it was packed! You definitely need a reservation, especially if you're coming in after 6pm.\n\nThey start you off with a thick piece of herby bread and butter and a jug of lemon water. To drink I tried a glass of the \"skin ferment\" wine, which I'd never heard of, but the servers insisted it was worth a try. It has a reddish orangey color, kind of like rum punch. And it tastes a bit like fruit juice or cider. It wasn't bad! I don't know that I would order it again with dinner, but it could be a fun drink-outside-with-your-friends wine, like rosé's cousin.\n\nFor dinner I went with the herb crusted salmon over a bed of roasted potatoes, tomatoes, and capers. It was pretty good, but I wasn't able to finish it. The salmon portion was huge and it was just drenched in herbs; too much for my taste. The potatoes and tomatoes were on point though!\n\nService is friendly, but slow. It took awhile for my order to be taken, and my wine came after my food. \n\nOverall a decent dinner. I'd be curious to try some of their other dishes.",
#         "language": "en"
#       },
#       "date": "2018-02-25T19:56:46Z",
#       "rating": 4,
#       "tags": [
#         "1 photo"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/ruGIljiLhdXRJM4-FrwbTQ/o.jpg",
#           "caption": "Salmon + glass of \"skin ferment\" wine"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 40,
#       "user": {
#         "name": "D L.",
#         "user_id": "fbA8BgUV7z5gLwy1XhiZ2Q",
#         "link": "https://www.yelp.com/user_details?userid=fbA8BgUV7z5gLwy1XhiZ2Q",
#         "address": "Los Angeles, CA",
#         "friends": 0,
#         "photos": 1,
#         "reviews": 15
#       },
#       "comment": {
#         "text": "The place is always packed so book ahead. But certainly worth the wait if you don't mind. The food was top notch - we had the beetroot soup which was beyond belief. Everything we ordered - including bread - was Michelin worthy. Highly recommended. Not the perfect place for dates though as it gets quite busy and a bit loud for romantic conversations.",
#         "language": "en"
#       },
#       "date": "2018-01-14T01:39:33Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 41,
#       "user": {
#         "name": "Cathy S.",
#         "user_id": "r0rw0xiwVRRKHz3wUcCZqA",
#         "link": "https://www.yelp.com/user_details?userid=r0rw0xiwVRRKHz3wUcCZqA",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/SCeK3IWbFynDU9vVs_F-gw/180s.jpg",
#         "address": "Glendale, AZ",
#         "friends": 158,
#         "photos": 41,
#         "reviews": 33
#       },
#       "comment": {
#         "text": "This place is delish. We have been here a few times and I've liked everything we have ordered! The wine is good and I didn't feel it was super overpriced.\n\nI'm not a big lamb fan but when my fiancé got it, I had to try. It was cooked well, melt in your mouth, and not overly lamby. I know that sounds weird but I find lamb has a very strong, pungent taste.\n\nDefinitely a must when on new regent street and Christchurch CBD in general. Just don't count the steps and you won't be disappointed.",
#         "language": "en"
#       },
#       "date": "2017-11-20T19:15:22Z",
#       "rating": 5,
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 42,
#       "user": {
#         "name": "Rami B.",
#         "user_id": "ntC4Cs6s1dbBDjwafZAptQ",
#         "link": "https://www.yelp.com/user_details?userid=ntC4Cs6s1dbBDjwafZAptQ",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/Ra2Ac_sN5VDadavfOl_lNA/180s.jpg",
#         "address": "Cupertino, CA",
#         "friends": 243,
#         "photos": 323,
#         "reviews": 81
#       },
#       "comment": {
#         "text": "Incredible rack of lamb. Probably the best I've had! Great service, ambience and presentation. Highly recommended, even if you find yourself in Christchurch for a day or so.",
#         "language": "en"
#       },
#       "date": "2017-03-22T08:57:13Z",
#       "rating": 5,
#       "tags": [
#         "4 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/S02mu9Y8BkMWWZ_aJhpJCQ/o.jpg",
#           "caption": "The rack!"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/28L_zEsKIVWNxyH5Jj7SKA/o.jpg",
#           "caption": "Signature door. Check out the logo on the wine glasses."
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/wojhRVhrtgfinyEKx9O5gQ/o.jpg",
#           "caption": "Ever changing menu"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/k6M4ZfwQSq6xs-rw1mBZ9w/o.jpg"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 43,
#       "user": {
#         "name": "Lauren T.",
#         "user_id": "YGcUF64YqnvQb9kwGLth2A",
#         "link": "https://www.yelp.com/user_details?userid=YGcUF64YqnvQb9kwGLth2A",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/gev20VtuDJuMUTNGFTllIg/180s.jpg",
#         "address": "Dallas, TX",
#         "friends": 22,
#         "photos": 231,
#         "reviews": 121
#       },
#       "comment": {
#         "text": "Wow! So many good things to say about this place. Definitely make a reservation as it is a cozy place with limited seating. \n\nTo begin, the decor is adorable and welcoming; the staff is super friendly and attentive; and the seating is comfortable and cozy. \n\nI sat alone, but had great conversation with the different staff. One of my servers discussed my wine tastes before letting me try two before settling on a glass. Both of her picks were spot on AND she let me know that a bottle was open that was not normally open so I could try a glass of that, as well. Really great service there. \n\nLet's start with the bread- homemade heaven with butter. Crumbles in your mouth. I don't normally eat bread- this bread is bomb.\n\nI was having trouble deciding on the menu since everything that was delivered near me looked and smelled amazing. \n\nI settled on the roasted red capsicum tomato and red onion soup with got cheese, terragon and lemon creme fraiche. While not a fan of goat cheese (AT ALL) this was a delight hunt of flavor in a wonderful soup. It's light and creamy but still satisfying and bursting with flavor. They also let me get a *teacup* size since I didn't want to ruin my appetite on the starter. \n\nFor the main, I chose the Pan fried salmon with capers, garlic crush potatoes, summer veg, and a banana prawns + lobster Marie Rose sauce topped with a cucumber salsa. The salmon fell apart on my plate. Even the roasted tomatoes on the side were amazing. \n\nI've had salmon 4 times while traveling NZ- this one takes the cake by far. This meal was fabulous and a great way to close out my New Zealand adventure.",
#         "language": "en"
#       },
#       "date": "2017-01-10T09:18:49Z",
#       "rating": 5,
#       "tags": [
#         "3 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/5kBXktE-YTJrxiaHX6ZY4w/o.jpg",
#           "caption": "Roast red capsicum tomatoe and red onion soup - tea cup size!"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/BJ32yWsHFrxgoSdZhzxI8g/o.jpg",
#           "caption": "Pan fried salmon with capers, garlic crushed potatoe, veg, banana prawn and lobster Marie rose and a cucumber salsa."
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/f-4nK5XCLXZZeQ2Nmm6-ww/o.jpg",
#           "caption": "Menu 1/10/17"
#         }
#       ],
#       "feedback": {
#         "useful": 1,
#         "funny": 0,
#         "cool": 1
#       }
#     },
#     {
#       "position": 44,
#       "user": {
#         "name": "Cindy H.",
#         "user_id": "cbGOTYFn4tZrfaDsNc-4Sw",
#         "link": "https://www.yelp.com/user_details?userid=cbGOTYFn4tZrfaDsNc-4Sw",
#         "address": "Toronto, Canada",
#         "friends": 0,
#         "photos": 55,
#         "reviews": 41
#       },
#       "comment": {
#         "text": "Came here for dinner on a Thursday night. The interior had a good ambience and felt cozy. Had to wait until 7:30 for the theatre crowd to finish dinner but the dinner itself was amazing.\nWe ordered the seared ox tongue special, rack of lamb, risotto, and an affogato with ameratto.\nEach dish was splendid, especially the ox tongue. Perfectly cooked inside, lightly seared outside. Would recommend to anyone visiting Christchurch.",
#         "language": "en"
#       },
#       "date": "2016-06-09T10:10:29Z",
#       "rating": 5,
#       "tags": [
#         "4 photos"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/Pd-okiKG7MdbMdiniGo2MQ/o.jpg",
#           "caption": "Seared ox tongue"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/oe_k6wHUTVbReHnT3CF_gw/o.jpg",
#           "caption": "Rack of lamb"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/Q4jKF_xJnLD0-9bdK7LBOQ/o.jpg",
#           "caption": "Risotto"
#         },
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/VkLPsxCg0nVqAvTJ4nRRyA/o.jpg",
#           "caption": "Affogato with ameratto"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 45,
#       "user": {
#         "name": "Allison W.",
#         "user_id": "h1dwawhwWMerDlCmC_BjAA",
#         "link": "https://www.yelp.com/user_details?userid=h1dwawhwWMerDlCmC_BjAA",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/iMEe8PTZZZkuNgFN8P2Ppg/180s.jpg",
#         "address": "Chicago, IL",
#         "friends": 92,
#         "photos": 3,
#         "reviews": 12
#       },
#       "comment": {
#         "text": "Wonderful service and the food was awesome. Loved supporting this business in central Christchurch while we were on holiday.",
#         "language": "en"
#       },
#       "date": "2016-06-06T02:04:01Z",
#       "rating": 5,
#       "tags": [
#         "1 photo"
#       ],
#       "photos": [
#         {
#           "link": "https://s3-media0.fl.yelpcdn.com/bphoto/9hXjk4rJ0kVQGZPMRDjf7g/o.jpg",
#           "caption": "Cute stop midway up the stairs"
#         }
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     },
#     {
#       "position": 46,
#       "user": {
#         "name": "Jessica E.",
#         "user_id": "hnX7SmJLX65ER4GVwXbWew",
#         "link": "https://www.yelp.com/user_details?userid=hnX7SmJLX65ER4GVwXbWew",
#         "thumbnail": "https://s3-media0.fl.yelpcdn.com/photo/wz3zeKdm_1_WapfMBkCBeg/180s.jpg",
#         "address": "Bozeman, MT",
#         "friends": 0,
#         "photos": 22,
#         "reviews": 21
#       },
#       "comment": {
#         "text": "Food was incredible, service was great and we never felt rushed even though they began to get busy during our time there.  Was a bit pricey but we think worth every penny!",
#         "language": "en"
#       },
#       "date": "2016-03-03T07:52:44Z",
#       "rating": 5,
#       "tags": [
#         "First to Review"
#       ],
#       "feedback": {
#         "useful": 0,
#         "funny": 0,
#         "cool": 0
#       }
#     }
#   ]
# }

# %% [markdown]
# ### READ THE RESTAURANT PLACE IDS ACROSS CHC

# %%
import pandas as pd

# %%
restaurant_id = pd.read_csv("Christchurch_place_ids.csv")

restaurant_id.head()
# Out:
#                           place_id               title  rating  reviews price  \
# 0           wEYj3B_EH6JS6DbfmZQudw  Twenty Seven Steps     4.8       48    $$
# 1  twenty-seven-steps-christchurch  Twenty Seven Steps     4.8       48    $$
# 2           5ZOai8-HCajxJ4gnjqsAdw                 OGB     4.9        9   NaN
# 3                 ogb-christchurch                 OGB     4.9        9   NaN
# 4           iL_451H-5M9tmaAsFqKZrw        Orange House     5.0        2   NaN
#
#           categories                                               link
# 0    Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 1    Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 2  Bars, New Zealand  https://www.yelp.com/biz/ogb-christchurch?osq=...
# 3  Bars, New Zealand  https://www.yelp.com/biz/ogb-christchurch?osq=...
# 4            Chinese  https://www.yelp.com/biz/orange-house-christch...

# %%
# 1️⃣ Find titles that appear more than once
dup_titles = (
    restaurant_id.groupby("title")
    .size()
    .reset_index(name="count")
    .query("count > 1")
    .sort_values("count", ascending=False)
)

print(f"🔁 Total duplicated restaurant titles: {len(dup_titles)}")

# 2️⃣ Display all rows (place_id + title) for duplicated titles
duplicate_details = (
    restaurant_id[restaurant_id["title"].isin(dup_titles["title"])]
    .loc[:, ["place_id", "title", "rating", "reviews", "price", "categories"]]
    .sort_values(["title", "place_id"])
    .reset_index(drop=True)
)

print("Sample of duplicated restaurants:")
duplicate_details.head(20)
# Out:
# 🔁 Total duplicated restaurant titles: 186
# Sample of duplicated restaurants:
#                                      place_id                         title  \
# 0                     5th-street-christchurch                    5th Street
# 1                      Busy8uaGSr4xVTDK64KCcg                    5th Street
# 2                      Bonsa2BwNhdqFWVmrn1Rag       Abalone Thai Restaurant
# 3   abalone-thai-restaurant-christchurch-city       Abalone Thai Restaurant
# 4                      5aSFsf5QbevEYxH3KTkRKA         Amaterrace Teppanyaki
# 5          amaterrace-teppanyaki-christchurch         Amaterrace Teppanyaki
# 6                      amazonita-christchurch                     Amazonita
# 7                      zHk2a3tQdyldANFOeqjR1A                     Amazonita
# 8                      FfB040u_JQh6PnbsrLQM_w                   Anna’s Cafe
# 9                     annas-cafe-christchurch                   Anna’s Cafe
# 10  antigua-boatsheds-canoe-hire-christchurch  Antigua Boatsheds Canoe Hire
# 11                     tZzZ6KZpBITfPH1c9YQhNQ  Antigua Boatsheds Canoe Hire
# 12                     arbo-cafe-christchurch                     Arbo Cafe
# 13                     y4jnOb4jgLMe029wAaABdA                     Arbo Cafe
# 14                     3SGm_b79hqJRgsWayAukxA                  Arjee Bhajee
# 15                arjee-bhajee-christchurch-2                  Arjee Bhajee
# 16                     NbKSaN-diw8E4S2ub2hXsQ          Aroy Thai Restaurant
# 17          aroy-thai-restaurant-christchurch          Aroy Thai Restaurant
# 18                     RDYakuJC8b6R_BWPDAGd4g                Bacon Brothers
# 19                bacon-brothers-christchurch                Bacon Brothers
#
#     rating  reviews price                                    categories
# 0      5.0        6   NaN  Wine Bars, Tapas/Small Plates, Cocktail Bars
# 1      5.0        6   NaN  Wine Bars, Tapas/Small Plates, Cocktail Bars
# 2      4.0        4   NaN                                          Thai
# 3      4.0        4   NaN                                          Thai
# 4      4.0        2   NaN                                    Teppanyaki
# 5      4.0        2   NaN                                    Teppanyaki
# 6      4.1       10   NaN                                 Mediterranean
# 7      4.1       10   NaN                                 Mediterranean
# 8      4.0        1   NaN                     Breakfast & Brunch, Cafes
# 9      4.0        1   NaN                     Breakfast & Brunch, Cafes
# 10     4.7        3    $$                           Coffee & Tea, Cafes
# 11     4.7        3    $$                           Coffee & Tea, Cafes
# 12     5.0        1   NaN                                         Cafes
# 13     5.0        1   NaN                                         Cafes
# 14     4.5        2   NaN                                        Indian
# 15     4.5        2   NaN                                        Indian
# 16     5.0        2   NaN                                   Restaurants
# 17     5.0        2   NaN                                   Restaurants
# 18     4.3       23     $         Breakfast & Brunch, Beer Bar, Burgers
# 19     4.3       23     $         Breakfast & Brunch, Beer Bar, Burgers

# %%
print("\n📋 List of all duplicated restaurant titles:\n")
for t in dup_titles["title"].tolist():
    print("-", t)
# Out:
# 📋 List of all duplicated restaurant titles:
#
# - Hachi Hachi
# - Spagalimis
# - McDonald’s
# - Fox & Ferret Public Ale House
# - Riccarton Noodle House
# - Pot Sticker Dumpling Bar
# - Prince of Persia
# - Pure Cafe Co.
# - Rangoon Ruby
# - Raw Sugar Cafe
# - Reality Bites
# - Red Elephant
# - Red Rock Cafe
# - Roast Ease
# - Pies and Coffee
# - Robert Harris
# - Rogues of Rotherham
# - Rose Cafe
# - Saigon Star
# - Sampan House Restaurant
# - Samurai Bowl
# - Sevanti Rest & Bar
# - Silver Dolphin
# - Portershed
# - 5th Street
# - Slick Burgers
# - Pescatore
# - Mitchelli’s Cafe Rinato
# - Monster Chicken
# - Morrell & Co
# - Mosaic by Simo
# - Mr Sushi
# - Mumbaiwala
# - Mum’s
# - Nobanno Restaurant Bar & Cafe
# - NomNom Kitchen
# - Noodle
# - Noodle Union
# - North and South Gourmet
# - OGB
# - Orange House
# - Original Sin
# - Orleans
# - Papas Pizza
# - Passengers & Co
# - Pedro’s House of Lamb
# - Pier Side Cafe
# - Smoke ‘n’ Barrel
# - Mexico Christchurch
# - Tutto Bene
# - The Rockpool
# - The Twisted Hop
# - The Watershed
# - Tiki Taco
# - Tony’s Teppan Yaki Japanese Restaurant
# - Town Tonic
# - Traiteur European Butchery
# - Trevinos
# - Tudor’s Restaurant and Bar
# - Twenty Seven Steps
# - Spice Paragon
# - Universo Brasserie & Bar
# - Unknown Chapter
# - Velvet Burger
# - Welcome Chinese Vegetarian Food
# - Wholly Bagels
# - Winnie Bagoes
# - Wok On In
# - Yoshi Japanese Restaurant
# - Zaffron
# - The Pedal Pusher
# - The Nook Eatery
# - The Lotus-Heart Vegetarian Restaurant
# - The Grey Robin
# - St Germain
# - Straits Cafe
# - Strawberry Fare
# - Styx and Stone
# - Sugarhorse
# - Sushi Soldier
# - Table of Munchies
# - Taste Of Egypt
# - Terrace Tavern
# - Thai Chef’s Restaurant
# - Thai Container
# - Thai Orchid Restaurant
# - The Afghan Restaurant
# - The Birdwood
# - The Bridge Restaurant & Bar
# - The Caffeine Laboratory
# - The Camden Restaurant & Bar
# - The China Kitchen
# - The Dragon Express Restaurant
# - Midnight Shanghai
# - Mexicali Fresh
# - Mexicano’s
# - Burgers & Beers
# - CHILLIKIWI
# - Cafe Mosaic
# - Cafe Sismo
# - Cafe Valentino
# - Casa Nostra Italian Kitchen
# - Cashel Thai
# - Cassels & Sons
# - ChiChi Kitchen
# - Chillingworth Road
# - Chiwahwah Mexican Cantina Bar
# - Chong’s Chinese Restaurant
# - Cleaver and Co
# - Coasters Tavern
# - Cook’n’ With Gas
# - Costas Taverna Greek Restaurant and Ouzo Bar
# - Crisp Cafe & Gifts
# - Curators House Restaurant
# - Dimitris Greek Food
# - Divine Cafe
# - CBD Bar & Pizzaria
# - Burgerfuel
# - Dux Central
# - BurgerFuel Spitfire Square
# - Amaterrace Teppanyaki
# - Amazonita
# - Anna’s Cafe
# - Antigua Boatsheds Canoe Hire
# - Arbo Cafe
# - Arjee Bhajee
# - Aroy Thai Restaurant
# - Bacon Brothers
# - Baretta
# - Base Woodfired Pizza
# - Beat Street
# - Benson Chinese Restaurant
# - Black Betty
# - Blax Espresso
# - Bloody Mary’s
# - Boo Radley’s Food & Liquor
# - Boteco Cafe & Bar
# - Buddha Stix
# - BurgerFuel Papanui
# - Dose Diner
# - Earl
# - Abalone Thai Restaurant
# - Inati
# - Johnny Sausage
# - Khmer Satay Noodle House
# - King of Charcoal
# - King of Snake
# - Kinji Japanese Restaurant
# - Leinster Road Bistro
# - Little High Eatery
# - Little India
# - Little Poms
# - Little Taipei
# - Lone Star
# - Lone Star Spitfire
# - Lyttleton Coffee Company
# - Madam Kwong’s Restaurant
# - Madam Woo Christchurch
# - Maddison’s Restaurant
# - Maharaja
# - Malaysia Delights
# - Mamacita’s
# - Joe’s Garage
# - Ilam Seafoods
# - Eden Alley
# - Holy Smoke
# - Edo Japanese Restaurant
# - Eightgrains Dumpling
# - Fiddlesticks
# - Fisherman’s Wharf
# - Formaggio’s Restaurant & Pizzeria
# - Francesca’s Italian Kitchen
# - Fresco Fisheries
# - Gatherings
# - Gourmet Seafoods Shirley
# - Great Wall Restaurant
# - Green Chilli Thai Restaurant and Takeaway
# - Gustavs Wine Bar
# - Harrington’s - Belfast
# - Hell Pizza
# - Hello Sunday
# - Hello Vietnam Restaurant
# - Hells Pizza
# - Hikari Sushi Bar
# - Himalayas Indian Restaurant & Takeaways
# - Zen

# %%
restaurant_id.columns
# Out:
# Index(['place_id', 'title', 'rating', 'reviews', 'price', 'categories',
#        'link'],
#       dtype='object')

# %%
restaurant_id.isnull().sum()
# Out:
# place_id        0
# title           0
# rating          0
# reviews         0
# price         252
# categories      0
# link            0
# dtype: int64

# %%
restaurant_id["place_id"].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### TEST SCRAPPED REVIEWS BASED ON RESTAURANT PLACE ID

# %%
import os
import json
import csv
import time
import requests
import pandas as pd

# %%
API_KEY = os.getenv("SERPAPI_API_KEY")  # make sure you ran: export SERPAPI_API_KEY="your_key"
BASE_URL = "https://serpapi.com/search"
INPUT_CSV = "data/Christchurch_place_ids.csv"  # the file from Stage 1
REVIEWS_PER_PAGE = 49

# %%
# Load place_ids csv 
df = pd.read_csv(INPUT_CSV)
first_place_id = df["place_id"].iloc[0]   # just test with the first one
print(f"Testing SerpApi review scrape for place_id: {first_place_id}")
# Out:
# Testing SerpApi review scrape for place_id: wEYj3B_EH6JS6DbfmZQudw

# %%
# --- Step 2: Build request parameters ---
params = {
    "api_key": API_KEY,
    "engine": "yelp_reviews",
    "place_id": first_place_id,
    "num": REVIEWS_PER_PAGE,
    "start": 0,
    "sortby": "date_desc"   # newest first
}

# %%
# --- Step 3: Send request to SerpApi ---
response = requests.get(BASE_URL, params=params, timeout=30)
response.raise_for_status()
data = response.json()

# %%
# --- Step 4: Inspect response structure ---
print("Top-level keys:", list(data.keys()))
print("Number of reviews fetched:", len(data.get("reviews", [])))
# Out:
# Top-level keys: ['search_metadata', 'search_parameters', 'search_information', 'review_languages', 'reviews']
# Number of reviews fetched: 46

# %%
# --- Step 5: Print a few sample reviews ---
for i, review in enumerate(data.get("reviews", [])[:5], start=1):
    user = review.get("user", {}).get("name")
    rating = review.get("rating")
    date = review.get("date")
    text = review.get("comment", {}).get("text", "")
    print(f"Review #{i}")
    print(f"User: {user}")
    print(f"Rating: {rating}")
    print(f"Date: {date}")
    print(f"Text: {text[:200]}...")
# Out:
# Review #1
# User: John B.
# Rating: 5
# Date: 2025-03-27T05:04:34Z
# Text: A warm greeting followed by a delicious dinner served by friendly happy servers .... What more can you want ?? I had read about their duck parfait app which to my dismay was not on the menu that night...
# Review #2
# User: Azure G.
# Rating: 5
# Date: 2025-02-14T04:09:56Z
# Text: Twenty Seven Steps - what a spot! Intimate space in a lovely location with great service, expansive wine selection and they are happy to make you a tasty mocktail that suits your palate.
#
# Now... the ...
# Review #3
# User: Calista C.
# Rating: 5
# Date: 2025-01-29T21:31:56Z
# Text: Visited here while on my stop in Christchurch. Easily the best meal I had in town. They're on the second floor, above their sister restaurant, Downstairs. Upon being seated, the server was extremely t...
# Review #4
# User: Jasper R.
# Rating: 5
# Date: 2024-11-20T04:47:31Z
# Text: Everything in here was amazing! One of my favorite places!
#
# The service is top-notch. They are so attentive and flexible depending on the needs of the table.
# The food is always on point and priced re...
# Review #5
# User: Andy M.
# Rating: 4
# Date: 2024-10-25T05:19:39Z
# Text: Cool atmosphere, great service, and the good food. The soup and monkfish was delicious!...

# %% [markdown]
# ### READ THE RESTAURANT REVIEW IN CHC

# %%
restaurant_reviews = pd.read_csv('christchurch_reviews_all_pages.csv')

restaurant_reviews.head()
# Out:
#                  place_id  review_type        user  rating  \
# 0  wEYj3B_EH6JS6DbfmZQudw  recommended     John B.       5
# 1  wEYj3B_EH6JS6DbfmZQudw  recommended    Azure G.       5
# 2  wEYj3B_EH6JS6DbfmZQudw  recommended  Calista C.       5
# 3  wEYj3B_EH6JS6DbfmZQudw  recommended   Jasper R.       5
# 4  wEYj3B_EH6JS6DbfmZQudw  recommended     Andy M.       4
#
#                    date                                               text  \
# 0  2025-03-27T05:04:34Z  A warm greeting followed by a delicious dinner...
# 1  2025-02-14T04:09:56Z  Twenty Seven Steps - what a spot! Intimate spa...
# 2  2025-01-29T21:31:56Z  Visited here while on my stop in Christchurch....
# 3  2024-11-20T04:47:31Z  Everything in here was amazing! One of my favo...
# 4  2024-10-25T05:19:39Z  Cool atmosphere, great service, and the good f...
#
#    review_position    user_address  useful  cool  funny  \
# 0                1    Falmouth, MA       0     0      0
# 1                2      Denver, CO       0     0      0
# 2                3      Irvine, CA       2     2      0
# 3                4     Lathrop, CA       0     0      0
# 4                5  Cincinnati, OH       0     0      0
#
#                                            user_link
# 0  https://www.yelp.com/user_details?userid=MgHxF...
# 1  https://www.yelp.com/user_details?userid=Z583n...
# 2  https://www.yelp.com/user_details?userid=PqR0K...
# 3  https://www.yelp.com/user_details?userid=IaX6k...
# 4  https://www.yelp.com/user_details?userid=ODxAj...

# %%
# Load reviews
reviews = pd.read_csv("data/christchurch_reviews_all_pages.csv")

# Example duplicate restaurant
duplicates = {
    "Twenty Seven Steps": ["wEYj3B_EH6JS6DbfmZQudw", "twenty-seven-steps-christchurch"]
}

for title, ids in duplicates.items():
    subset = reviews[reviews["place_id"].isin(ids)]
    print(f"=== {title} ===")
    print(f"Total reviews scraped: {len(subset)}")
    print(f"Unique reviews (by user + date + text): {len(subset.drop_duplicates(subset=['user','date','text']))}")
    print()
# Out:
# === Twenty Seven Steps ===
# Total reviews scraped: 46
# Unique reviews (by user + date + text): 46

# %%
# Load datasets
places = pd.read_csv("data/Christchurch_place_ids.csv")[["place_id", "title"]]
reviews = pd.read_csv("data/christchurch_reviews_all_pages.csv")[["place_id", "user", "date", "text", "rating"]]

# Normalize restaurant titles (case-insensitive, strip spaces)
places["title_lower"] = places["title"].str.lower().str.strip()

# Find restaurants with multiple place_ids
duplicate_titles = (
    places.groupby("title_lower")
    .filter(lambda x: len(x["place_id"].unique()) > 1)
)

# Create a list of results
results = []

for title, group in duplicate_titles.groupby("title_lower"):
    place_ids = group["place_id"].tolist()
    title_original = group["title"].iloc[0]
    
    # Get all reviews for these place_ids
    sub_reviews = reviews[reviews["place_id"].isin(place_ids)]
    
    if sub_reviews.empty:
        results.append({
            "title": title_original,
            "place_ids": place_ids,
            "has_reviews": False,
            "review_overlap": "N/A (no reviews)"
        })
        continue
    
    # Check total and unique review texts
    total_reviews = len(sub_reviews)
    unique_texts = len(sub_reviews.drop_duplicates(subset=["user", "text", "date"]))
    
    identical = total_reviews == unique_texts
    
    # Determine overlap between the place_ids
    overlap_ratio = unique_texts / total_reviews if total_reviews else 0
    
    results.append({
        "title": title_original,
        "place_ids": place_ids,
        "total_reviews": total_reviews,
        "unique_texts": unique_texts,
        "overlap_ratio": round(overlap_ratio, 3),
        "review_overlap": "identical" if identical else "different"
    })

# Convert to DataFrame
review_overlap_df = pd.DataFrame(results)

# Sort to show the different ones first
review_overlap_df = review_overlap_df.sort_values(by="review_overlap", ascending=True).reset_index(drop=True)

# Display
print(f"Total restaurants checked: {len(review_overlap_df)}")
review_overlap_df.head(20)
# Out:
# Total restaurants checked: 186
#                        title  \
# 0                 5th Street
# 1            Pies and Coffee
# 2                 Portershed
# 3   Pot Sticker Dumpling Bar
# 4           Prince of Persia
# 5              Pure Cafe Co.
# 6               Rangoon Ruby
# 7             Raw Sugar Cafe
# 8              Reality Bites
# 9               Red Elephant
# 10             Red Rock Cafe
# 11    Riccarton Noodle House
# 12                Roast Ease
# 13             Robert Harris
# 14       Rogues of Rotherham
# 15                 Rose Cafe
# 16               Saigon Star
# 17   Sampan House Restaurant
# 18              Samurai Bowl
# 19        Sevanti Rest & Bar
#
#                                             place_ids  total_reviews  \
# 0   [Busy8uaGSr4xVTDK64KCcg, 5th-street-christchurch]              6
# 1   [IO-ZvolUGtPAJScNnRDGrA, pies-and-coffee-chris...              1
# 2   [o7caz3L5WXwMpwe2xKVoUg, portershed-christchurch]              3
# 3   [Do7ayiKlaaYwppPZ3CRYWw, pot-sticker-dumpling-...             12
# 4   [xY8ObYwNWUGknGmZNSvBXQ, prince-of-persia-chri...              1
# 5   [pg1DJsdU9vSp6WLJcxRxAw, pure-cafe-co-christch...              1
# 6   [nCARbbvdnfXT82QCTE4igA, rangoon-ruby-christch...              5
# 7   [BvIxqkZtptUFvW1TmupRIQ, raw-sugar-cafe-christ...              1
# 8   [ZMIUHjkp5PyG2JumFrd7yw, reality-bites-christc...              1
# 9   [9IH4d4GfvmlDL1LpazUt7Q, red-elephant-christch...              1
# 10  [-EYNkEGPRoyInE9COjJnNA, red-rock-cafe-christc...              2
# 11  [f5WbfkjUOMMofXvpxK-nZw, riccarton-noodle-hous...              3
# 12  [4-5FjG5FLJnhezry9nqRxw, roast-ease-christchurch]              1
# 13  [_6Kg47EfSZEAcO6iXMjD_w, robert-harris-christc...              1
# 14  [VWaIKdFB-Y0wfNn0EyLk3g, rogues-of-rotherham-c...              1
# 15   [jQpxVmSuo1zF8CiBAaKCUw, rose-cafe-christchurch]              2
# 16  [M80xGBCVqm2FeFQHSluz0A, saigon-star-christchu...              1
# 17  [qkLJmx__gkLiqGXvm9GRCA, sampan-house-restaura...              7
# 18  [ZVYKvu_01xFMlg1q1dwz7A, samurai-bowl-christch...              6
# 19  [_MJXPoOfH2yO7kh_bgbzSA, sevanti-rest-and-bar-...              1
#
#     unique_texts  overlap_ratio review_overlap
# 0              6            1.0      identical
# 1              1            1.0      identical
# 2              3            1.0      identical
# 3             12            1.0      identical
# 4              1            1.0      identical
# 5              1            1.0      identical
# 6              5            1.0      identical
# 7              1            1.0      identical
# 8              1            1.0      identical
# 9              1            1.0      identical
# 10             2            1.0      identical
# 11             3            1.0      identical
# 12             1            1.0      identical
# 13             1            1.0      identical
# 14             1            1.0      identical
# 15             2            1.0      identical
# 16             1            1.0      identical
# 17             7            1.0      identical
# 18             6            1.0      identical
# 19             1            1.0      identical

# %%
review_overlap_df['review_overlap'].value_counts()
# Out:
# review_overlap
# identical    186
# Name: count, dtype: int64

# %% [markdown]
# ### HANDLE DUPLICATE IN PLACE_ID PER RESTAURANT

# %%
restaurant_id.head()
# Out:
#                           place_id               title  rating  reviews price  \
# 0           wEYj3B_EH6JS6DbfmZQudw  Twenty Seven Steps     4.8       48    $$
# 1  twenty-seven-steps-christchurch  Twenty Seven Steps     4.8       48    $$
# 2           5ZOai8-HCajxJ4gnjqsAdw                 OGB     4.9        9   NaN
# 3                 ogb-christchurch                 OGB     4.9        9   NaN
# 4           iL_451H-5M9tmaAsFqKZrw        Orange House     5.0        2   NaN
#
#           categories                                               link
# 0    Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 1    Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 2  Bars, New Zealand  https://www.yelp.com/biz/ogb-christchurch?osq=...
# 3  Bars, New Zealand  https://www.yelp.com/biz/ogb-christchurch?osq=...
# 4            Chinese  https://www.yelp.com/biz/orange-house-christch...

# %%
# Find edge-case restaurants (≥3 place_ids and mix of hash/slug)
import pandas as pd

# Start from your loaded DataFrame
df = restaurant_id.copy()
df["title_lower"] = df["title"].str.lower().str.strip()

# Heuristic: Yelp hash IDs have NO hyphen and at least one uppercase char
def is_hash(pid: str) -> bool:
    s = str(pid)
    return ("-" not in s) and any(c.isupper() for c in s)

df["is_hash"] = df["place_id"].apply(is_hash)
df["is_slug"] = ~df["is_hash"]

# Group stats per restaurant
grp = (
    df.groupby("title_lower")
      .agg(
          num_ids=("place_id", "nunique"),
          num_hash=("is_hash", "sum"),
          num_slug=("is_slug", "sum")
      )
      .reset_index()
)

# Edge case definition: at least 3 ids AND both hash & slug present
edge_titles = grp.query("num_ids >= 3 and num_hash >= 1 and num_slug >= 1").copy()

print(f"Edge-case restaurants found: {len(edge_titles)}")
edge_titles.head(10)
# Out:
# Edge-case restaurants found: 3
#                       title_lower  num_ids  num_hash  num_slug
# 53  fox & ferret public ale house        4         2         2
# 61                    hachi hachi        6         3         3
# 92                     mcdonald’s        4         2         2

# %%
# Inspect all rows for those edge-case titles
edge_rows = (
    df[df["title_lower"].isin(edge_titles["title_lower"])]
    .sort_values(["title_lower"])  # keeps original row order within each title
    .reset_index(drop=True)
)

edge_rows[["title", "place_id", "is_hash", "rating", "reviews", "categories"]].head(30)
# Out:
#                             title  \
# 0   Fox & Ferret Public Ale House
# 1   Fox & Ferret Public Ale House
# 2   Fox & Ferret Public Ale House
# 3   Fox & Ferret Public Ale House
# 4                     Hachi Hachi
# 5                     Hachi Hachi
# 6                     Hachi Hachi
# 7                     Hachi Hachi
# 8                     Hachi Hachi
# 9                     Hachi Hachi
# 10                     McDonald’s
# 11                     McDonald’s
# 12                     McDonald’s
# 13                     McDonald’s
#
#                                           place_id  is_hash  rating  reviews  \
# 0                           o0io1bT7fN4rsam461_j_g     True     4.0        1
# 1     fox-and-ferret-public-ale-house-christchurch    False     4.0        1
# 2                           LceHmZ1Z2pCl1WrVnVNptA     True     2.6        8
# 3   fox-and-ferret-public-ale-house-christchurch-2    False     2.6        8
# 4                           MWnLwbV6tyBEj1LCd15lAQ     True     3.8       11
# 5                       hachi-hachi-christchurch-2    False     3.8       11
# 6                           W3bRohV8kGbiTAWLMu9SUw     True     3.2        5
# 7                       hachi-hachi-christchurch-3    False     3.2        5
# 8                           dwebhjgrd7u1pjADqZH2RA     True     2.0        1
# 9                         hachi-hachi-christchurch    False     2.0        1
# 10                          5xrpVuUVwbkVURjJYiq4XQ     True     5.0        1
# 11                        mcdonalds-christchurch-2    False     5.0        1
# 12                          8UcIcdTWPSIEyMOAcUbXEw     True     2.5        2
# 13                        mcdonalds-christchurch-4    False     2.5        2
#
#                        categories
# 0                     New Zealand
# 1                     New Zealand
# 2                     New Zealand
# 3                     New Zealand
# 4                        Japanese
# 5                        Japanese
# 6   Japanese, Sushi Bars, Noodles
# 7   Japanese, Sushi Bars, Noodles
# 8                        Japanese
# 9                        Japanese
# 10                    Restaurants
# 11                    Restaurants
# 12             Fast Food, Burgers
# 13             Fast Food, Burgers

# %%
# Keep only hash IDs for these edge-case restaurants
clean_edge = df[
    ~((df["title_lower"].isin(edge_titles["title_lower"])) & (df["is_slug"]))
].reset_index(drop=True)

print(f"Original rows: {len(df)}")
print(f"After removing slugs (only for ≥3-ID mixed titles): {len(clean_edge)}")
# Out:
# Original rows: 382
# After removing slugs (only for ≥3-ID mixed titles): 375

# %% [markdown]
# - remove duplicate place_ids per restaurant title (keeping the first),
#
# - but skip the 3 special cases:
# - "Fox & Ferret Public Ale House", "Hachi Hachi", and "McDonald’s" —
# - because these have multiple hash IDs with different review counts that you’ll manually inspect later.

# %%
df_cleaned_edge = clean_edge

# Define your edge-case titles
edge_case_titles = ["Fox & Ferret Public Ale House", "Hachi Hachi", "McDonald’s"]

# Normalize title for consistency
df_cleaned_edge["title_lower"] = df_cleaned_edge["title"].str.lower().str.strip()

# Filter out the edge cases for now
non_edge = df_cleaned_edge[~df_cleaned_edge["title"].isin(edge_case_titles)]

# Drop duplicates among non-edge titles (keep first place_id)
non_edge_unique = non_edge.drop_duplicates(subset="title_lower", keep="first")

# Combine back edge cases (keep all their hashed IDs)
restaurant_final = pd.concat([non_edge_unique, df_cleaned_edge[df_cleaned_edge["title"].isin(edge_case_titles)]], ignore_index=True)

print(f"Original rows: {len(df_cleaned_edge)}")
print(f"After cleaning (keeping all hash IDs for edge cases): {len(restaurant_final)}")

# Preview result
restaurant_final.sort_values("title").head(15)
# Out:
# Original rows: 375
# After cleaning (keeping all hash IDs for edge cases): 190
#                    place_id                         title  rating  reviews  \
# 4    Busy8uaGSr4xVTDK64KCcg                    5th Street     5.0        6
# 99   Bonsa2BwNhdqFWVmrn1Rag       Abalone Thai Restaurant     4.0        4
# 75   5aSFsf5QbevEYxH3KTkRKA         Amaterrace Teppanyaki     4.0        2
# 21   zHk2a3tQdyldANFOeqjR1A                     Amazonita     4.1       10
# 152  FfB040u_JQh6PnbsrLQM_w                   Anna’s Cafe     4.0        1
# 176  tZzZ6KZpBITfPH1c9YQhNQ  Antigua Boatsheds Canoe Hire     4.7        3
# 170  y4jnOb4jgLMe029wAaABdA                     Arbo Cafe     5.0        1
# 103  3SGm_b79hqJRgsWayAukxA                  Arjee Bhajee     4.5        2
# 76   NbKSaN-diw8E4S2ub2hXsQ          Aroy Thai Restaurant     5.0        2
# 25   RDYakuJC8b6R_BWPDAGd4g                Bacon Brothers     4.3       23
# 135  TuxIaLO5I33JKPsRt-IUoA                       Baretta     3.0        9
# 10   asIl2NNXPqg94JjC_Oyilg          Base Woodfired Pizza     4.9       16
# 144  A6CKAkDkccjl7cAUaCjuqA                   Beat Street     4.2        5
# 118  vG7Bx-lV2eAmp1_AgjcWuA     Benson Chinese Restaurant     3.0        2
# 46   uQIitI1Zd4Q7PT2z4Oj8rg                   Black Betty     4.2       44
#
#     price                                    categories  \
# 4     NaN  Wine Bars, Tapas/Small Plates, Cocktail Bars
# 99    NaN                                          Thai
# 75    NaN                                    Teppanyaki
# 21    NaN                                 Mediterranean
# 152   NaN                     Breakfast & Brunch, Cafes
# 176    $$                           Coffee & Tea, Cafes
# 170   NaN                                         Cafes
# 103   NaN                                        Indian
# 76    NaN                                   Restaurants
# 25      $         Breakfast & Brunch, Beer Bar, Burgers
# 135   $$$                                 Bars, Italian
# 10      $                                         Pizza
# 144   NaN                                         Cafes
# 118   NaN                     Chinese, Seafood, Noodles
# 46     $$              Coffee & Tea, Breakfast & Brunch
#
#                                                   link  \
# 4    https://www.yelp.com/biz/5th-street-christchur...
# 99   https://www.yelp.com/biz/abalone-thai-restaura...
# 75   https://www.yelp.com/biz/amaterrace-teppanyaki...
# 21   https://www.yelp.com/biz/amazonita-christchurc...
# 152  https://www.yelp.com/biz/annas-cafe-christchur...
# 176  https://www.yelp.com/biz/antigua-boatsheds-can...
# 170  https://www.yelp.com/biz/arbo-cafe-christchurc...
# 103  https://www.yelp.com/biz/arjee-bhajee-christch...
# 76   https://www.yelp.com/biz/aroy-thai-restaurant-...
# 25   https://www.yelp.com/biz/bacon-brothers-christ...
# 135  https://www.yelp.com/biz/baretta-christchurch?...
# 10   https://www.yelp.com/biz/base-woodfired-pizza-...
# 144  https://www.yelp.com/biz/beat-street-christchu...
# 118  https://www.yelp.com/biz/benson-chinese-restau...
# 46   https://www.yelp.com/biz/black-betty-christchu...
#
#                       title_lower  is_hash  is_slug
# 4                      5th street     True    False
# 99        abalone thai restaurant     True    False
# 75          amaterrace teppanyaki     True    False
# 21                      amazonita     True    False
# 152                   anna’s cafe     True    False
# 176  antigua boatsheds canoe hire     True    False
# 170                     arbo cafe     True    False
# 103                  arjee bhajee     True    False
# 76           aroy thai restaurant    False     True
# 25                 bacon brothers     True    False
# 135                       baretta    False     True
# 10           base woodfired pizza     True    False
# 144                   beat street     True    False
# 118     benson chinese restaurant    False     True
# 46                    black betty     True    False

# %%
restaurant_final.to_csv("Christchurch_place_ids_cleaned.csv", index=False)
print("Saved final cleaned file: Christchurch_place_ids_cleaned.csv")
# Out:
# Saved final cleaned file: Christchurch_place_ids_cleaned.csv

# %%
df_reviews = pd.read_csv("christchurch_reviews_all_pages.csv")

df_reviews.head()
# Out:
#                  place_id  review_type        user  rating  \
# 0  wEYj3B_EH6JS6DbfmZQudw  recommended     John B.       5
# 1  wEYj3B_EH6JS6DbfmZQudw  recommended    Azure G.       5
# 2  wEYj3B_EH6JS6DbfmZQudw  recommended  Calista C.       5
# 3  wEYj3B_EH6JS6DbfmZQudw  recommended   Jasper R.       5
# 4  wEYj3B_EH6JS6DbfmZQudw  recommended     Andy M.       4
#
#                    date                                               text  \
# 0  2025-03-27T05:04:34Z  A warm greeting followed by a delicious dinner...
# 1  2025-02-14T04:09:56Z  Twenty Seven Steps - what a spot! Intimate spa...
# 2  2025-01-29T21:31:56Z  Visited here while on my stop in Christchurch....
# 3  2024-11-20T04:47:31Z  Everything in here was amazing! One of my favo...
# 4  2024-10-25T05:19:39Z  Cool atmosphere, great service, and the good f...
#
#    review_position    user_address  useful  cool  funny  \
# 0                1    Falmouth, MA       0     0      0
# 1                2      Denver, CO       0     0      0
# 2                3      Irvine, CA       2     2      0
# 3                4     Lathrop, CA       0     0      0
# 4                5  Cincinnati, OH       0     0      0
#
#                                            user_link
# 0  https://www.yelp.com/user_details?userid=MgHxF...
# 1  https://www.yelp.com/user_details?userid=Z583n...
# 2  https://www.yelp.com/user_details?userid=PqR0K...
# 3  https://www.yelp.com/user_details?userid=IaX6k...
# 4  https://www.yelp.com/user_details?userid=ODxAj...

# %%
df_reviews["place_id"].nunique()
# Out:
# 190

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1086 entries, 0 to 1085
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   place_id         1086 non-null   object
#  1   review_type      1086 non-null   object
#  2   user             1086 non-null   object
#  3   rating           1086 non-null   int64
#  4   date             1086 non-null   object
#  5   text             1086 non-null   object
#  6   review_position  1086 non-null   int64
#  7   user_address     1086 non-null   object
#  8   useful           1086 non-null   int64
#  9   cool             1086 non-null   int64
#  10  funny            1086 non-null   int64
#  11  user_link        1086 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 101.9+ KB

# %%
restaurant_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   place_id     190 non-null    object
#  1   title        190 non-null    object
#  2   rating       190 non-null    float64
#  3   reviews      190 non-null    int64
#  4   price        65 non-null     object
#  5   categories   190 non-null    object
#  6   link         190 non-null    object
#  7   title_lower  190 non-null    object
#  8   is_hash      190 non-null    bool
#  9   is_slug      190 non-null    bool
# dtypes: bool(2), float64(1), int64(1), object(6)
# memory usage: 12.4+ KB

# %%
# Join 2 columns 
# Select only the needed columns from restaurant_final
restaurant_info = restaurant_final[["place_id", "title", "price", "categories", "link"]]

# Merge on place_id (left join to keep all reviews)
chc_reviews_df = df_reviews.merge(restaurant_info, on="place_id", how="left")

# Preview result
print(f"Original reviews: {len(df_reviews)}")
print(f"Merged reviews: {len(chc_reviews_df)}")
chc_reviews_df.head()
# Out:
# Original reviews: 1086
# Merged reviews: 1086
#                  place_id  review_type        user  rating  \
# 0  wEYj3B_EH6JS6DbfmZQudw  recommended     John B.       5
# 1  wEYj3B_EH6JS6DbfmZQudw  recommended    Azure G.       5
# 2  wEYj3B_EH6JS6DbfmZQudw  recommended  Calista C.       5
# 3  wEYj3B_EH6JS6DbfmZQudw  recommended   Jasper R.       5
# 4  wEYj3B_EH6JS6DbfmZQudw  recommended     Andy M.       4
#
#                    date                                               text  \
# 0  2025-03-27T05:04:34Z  A warm greeting followed by a delicious dinner...
# 1  2025-02-14T04:09:56Z  Twenty Seven Steps - what a spot! Intimate spa...
# 2  2025-01-29T21:31:56Z  Visited here while on my stop in Christchurch....
# 3  2024-11-20T04:47:31Z  Everything in here was amazing! One of my favo...
# 4  2024-10-25T05:19:39Z  Cool atmosphere, great service, and the good f...
#
#    review_position    user_address  useful  cool  funny  \
# 0                1    Falmouth, MA       0     0      0
# 1                2      Denver, CO       0     0      0
# 2                3      Irvine, CA       2     2      0
# 3                4     Lathrop, CA       0     0      0
# 4                5  Cincinnati, OH       0     0      0
#
#                                            user_link               title  \
# 0  https://www.yelp.com/user_details?userid=MgHxF...  Twenty Seven Steps
# 1  https://www.yelp.com/user_details?userid=Z583n...  Twenty Seven Steps
# 2  https://www.yelp.com/user_details?userid=PqR0K...  Twenty Seven Steps
# 3  https://www.yelp.com/user_details?userid=IaX6k...  Twenty Seven Steps
# 4  https://www.yelp.com/user_details?userid=ODxAj...  Twenty Seven Steps
#
#   price       categories                                               link
# 0    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 1    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 2    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 3    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 4    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...

# %%
chc_reviews_df["date"] = pd.to_datetime(chc_reviews_df["date"], errors="coerce")
chc_reviews_df["title"] = chc_reviews_df["title"].str.lower().str.strip()

# %%
chc_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1086 entries, 0 to 1085
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   place_id         1086 non-null   object
#  1   review_type      1086 non-null   object
#  2   user             1086 non-null   object
#  3   rating           1086 non-null   int64
#  4   date             1086 non-null   datetime64[ns]
#  5   text             1086 non-null   object
#  6   review_position  1086 non-null   int64
#  7   user_address     1086 non-null   object
#  8   useful           1086 non-null   int64
#  9   cool             1086 non-null   int64
#  10  funny            1086 non-null   int64
#  11  user_link        1086 non-null   object
#  12  title            1086 non-null   object
#  13  price            710 non-null    object
#  14  categories       1086 non-null   object
#  15  link             1086 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(10)
# memory usage: 135.9+ KB

# %%
chc_reviews_df.head()
# Out:
#                  place_id  review_type        user  rating  \
# 0  wEYj3B_EH6JS6DbfmZQudw  recommended     John B.       5
# 1  wEYj3B_EH6JS6DbfmZQudw  recommended    Azure G.       5
# 2  wEYj3B_EH6JS6DbfmZQudw  recommended  Calista C.       5
# 3  wEYj3B_EH6JS6DbfmZQudw  recommended   Jasper R.       5
# 4  wEYj3B_EH6JS6DbfmZQudw  recommended     Andy M.       4
#
#                  date                                               text  \
# 0 2025-03-27 05:04:34  A warm greeting followed by a delicious dinner...
# 1 2025-02-14 04:09:56  Twenty Seven Steps - what a spot! Intimate spa...
# 2 2025-01-29 21:31:56  Visited here while on my stop in Christchurch....
# 3 2024-11-20 04:47:31  Everything in here was amazing! One of my favo...
# 4 2024-10-25 05:19:39  Cool atmosphere, great service, and the good f...
#
#    review_position    user_address  useful  cool  funny  \
# 0                1    Falmouth, MA       0     0      0
# 1                2      Denver, CO       0     0      0
# 2                3      Irvine, CA       2     2      0
# 3                4     Lathrop, CA       0     0      0
# 4                5  Cincinnati, OH       0     0      0
#
#                                            user_link               title  \
# 0  https://www.yelp.com/user_details?userid=MgHxF...  twenty seven steps
# 1  https://www.yelp.com/user_details?userid=Z583n...  twenty seven steps
# 2  https://www.yelp.com/user_details?userid=PqR0K...  twenty seven steps
# 3  https://www.yelp.com/user_details?userid=IaX6k...  twenty seven steps
# 4  https://www.yelp.com/user_details?userid=ODxAj...  twenty seven steps
#
#   price       categories                                               link
# 0    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 1    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 2    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 3    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 4    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...

# %%
# Find duplicate place_id with same title
# Count how many unique place_id per title
title_placeid_counts = (
    chc_reviews_df.groupby("title")["place_id"]
    .nunique()
    .reset_index(name="unique_place_ids")
)

# Filter where the same title has more than one place_id
titles_with_multiple_ids = title_placeid_counts[title_placeid_counts["unique_place_ids"] > 1]

print(f"Total titles with multiple place_ids: {len(titles_with_multiple_ids)}")

# Show a few examples
titles_with_multiple_ids.head(20)
# Out:
# Total titles with multiple place_ids: 3
#                             title  unique_place_ids
# 53  fox & ferret public ale house                 2
# 61                    hachi hachi                 3
# 92                     mcdonald’s                 2

# %%
# Get all rows for titles that have more than one unique place_id
duplicate_placeid_rows = (
    chc_reviews_df[chc_reviews_df["title"].isin(titles_with_multiple_ids["title"])]
    .sort_values(["title", "place_id"])
    .reset_index(drop=True)
)

print(f"Total rows from titles with multiple place_ids: {len(duplicate_placeid_rows)}")

# Display a sample
duplicate_placeid_rows[["title", "place_id", "rating", "date", "text"]].head(20)
# Out:
# Total rows from titles with multiple place_ids: 29
#                             title                place_id  rating  \
# 0   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       1
# 1   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       4
# 2   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       5
# 3   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       1
# 4   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       2
# 5   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       2
# 6   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       4
# 7   fox & ferret public ale house  LceHmZ1Z2pCl1WrVnVNptA       2
# 8   fox & ferret public ale house  o0io1bT7fN4rsam461_j_g       4
# 9                     hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       4
# 10                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       4
# 11                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       4
# 12                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       1
# 13                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       4
# 14                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       5
# 15                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       4
# 16                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       4
# 17                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       5
# 18                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       3
# 19                    hachi hachi  MWnLwbV6tyBEj1LCd15lAQ       4
#
#                   date                                               text
# 0  2018-02-01 23:55:41  Wouldn't serve me a beer even though I'm 27, 6...
# 1  2017-01-08 00:15:42  Had a great meal with my family here. Staff wa...
# 2  2016-07-25 05:06:23  We loved it! Great atmosphere, live music, gre...
# 3  2015-12-19 23:31:51  Went in at 5pm for a pint OF COKE(!) and was I...
# 4  2015-10-29 23:32:22  The Halloween themed party was very fitting la...
# 5  2015-10-10 00:15:14  Its a nice pub with a good vibe. Its good for ...
# 6  2014-09-26 23:27:57  Reviewing on visiting during a pre lunch week ...
# 7  2014-09-14 10:03:12  I find the only good time to go drinking in th...
# 8  2015-06-29 02:41:56  This is a pretty great bar located in The Palm...
# 9  2025-03-06 01:44:58  My husband and I had lunch here. I was craving...
# 10 2024-05-12 22:21:47  Nice place for something casual and food was g...
# 11 2019-10-17 00:12:48  A good Japanese restaurant with quick service ...
# 12 2017-09-17 07:26:09  This is not Japanese food. I ordered the N1 ud...
# 13 2017-02-06 05:10:15  We opted for sushi since we're originally from...
# 14 2017-01-13 07:31:48  The verity at this restaurant his amazing, fre...
# 15 2016-07-04 03:16:51  I enjoyed the few times I went in here for eit...
# 16 2015-11-27 23:04:21  this is a Japanese restaurant but they don't s...
# 17 2015-11-18 20:06:35  Hachi hachi,is the best sushi in town,actually...
# 18 2015-07-20 22:42:19  This is a great and fast Japanese sit-down/tak...
# 19 2014-10-29 09:35:22  Whilst in Christchurch met up with my coworker...

# %% [markdown]
# ### HANDLE DUPLICATE PLACE_ID - SAME TITLE - DIFFERENT REVIEWS
# - we will convert it to keep the most recent place_id only

# %%
# Step 2: Find the most recent place_id per restaurant title
latest_per_place = (
    chc_reviews_df.groupby(["title", "place_id"])["date"]
    .max()
    .reset_index()
)

# %%
# Step 3: For each title, get the place_id with the newest date
newest_place_ids = (
    latest_per_place.sort_values(["title", "date"], ascending=[True, False])
    .drop_duplicates(subset=["title"], keep="first")
    .rename(columns={"place_id": "canonical_place_id"})
    [["title", "canonical_place_id"]]
)

# %%
# Step 4: Merge back — map all old place_ids to the canonical one
chc_reviews_unified = chc_reviews_df.merge(
    newest_place_ids, on="title", how="left"
)

# %%
# Step 5: Replace place_id with canonical id
chc_reviews_unified["place_id"] = chc_reviews_unified["canonical_place_id"]
chc_reviews_unified = chc_reviews_unified.drop(columns=["canonical_place_id"])

print(f"All reviews unified. Total reviews: {len(chc_reviews_unified)}")
print(f"Unique place_ids before: {chc_reviews_df['place_id'].nunique()}")
print(f"Unique place_ids after: {chc_reviews_unified['place_id'].nunique()}")
# Out:
# All reviews unified. Total reviews: 1086
# Unique place_ids before: 190
# Unique place_ids after: 186

# %%
chc_reviews_unified[["title", "place_id", "rating", "date"]].head(10)
# Out:
#                 title                place_id  rating                date
# 0  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2025-03-27 05:04:34
# 1  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2025-02-14 04:09:56
# 2  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2025-01-29 21:31:56
# 3  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2024-11-20 04:47:31
# 4  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       4 2024-10-25 05:19:39
# 5  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2024-07-21 06:25:26
# 6  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2024-05-15 09:22:11
# 7  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       4 2024-04-12 06:52:26
# 8  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2024-04-06 05:38:35
# 9  twenty seven steps  wEYj3B_EH6JS6DbfmZQudw       5 2023-12-22 00:21:34

# %%
chc_reviews_unified['place_id'].nunique()
# Out:
# 186

# %%
chc_reviews_unified['title'].nunique()
# Out:
# 186

# %%
# check the edge cases
target_titles = ["hachi hachi", "mcdonald’s", "fox & ferret public ale house"]

# Filter only those titles
selected_restaurants = (
    chc_reviews_unified[chc_reviews_unified["title"].isin(target_titles)]
    .groupby("title")["place_id"]
    .unique()
    .reset_index()
)

print("Canonical place_id(s) for selected restaurants:")
selected_restaurants
# Out:
# Canonical place_id(s) for selected restaurants:
#                            title                  place_id
# 0  fox & ferret public ale house  [LceHmZ1Z2pCl1WrVnVNptA]
# 1                    hachi hachi  [MWnLwbV6tyBEj1LCd15lAQ]
# 2                     mcdonald’s  [8UcIcdTWPSIEyMOAcUbXEw]

# %%
chc_reviews_df = chc_reviews_unified

# %%
chc_reviews_df.head()
# Out:
#                  place_id  review_type        user  rating  \
# 0  wEYj3B_EH6JS6DbfmZQudw  recommended     John B.       5
# 1  wEYj3B_EH6JS6DbfmZQudw  recommended    Azure G.       5
# 2  wEYj3B_EH6JS6DbfmZQudw  recommended  Calista C.       5
# 3  wEYj3B_EH6JS6DbfmZQudw  recommended   Jasper R.       5
# 4  wEYj3B_EH6JS6DbfmZQudw  recommended     Andy M.       4
#
#                  date                                               text  \
# 0 2025-03-27 05:04:34  A warm greeting followed by a delicious dinner...
# 1 2025-02-14 04:09:56  Twenty Seven Steps - what a spot! Intimate spa...
# 2 2025-01-29 21:31:56  Visited here while on my stop in Christchurch....
# 3 2024-11-20 04:47:31  Everything in here was amazing! One of my favo...
# 4 2024-10-25 05:19:39  Cool atmosphere, great service, and the good f...
#
#    review_position    user_address  useful  cool  funny  \
# 0                1    Falmouth, MA       0     0      0
# 1                2      Denver, CO       0     0      0
# 2                3      Irvine, CA       2     2      0
# 3                4     Lathrop, CA       0     0      0
# 4                5  Cincinnati, OH       0     0      0
#
#                                            user_link               title  \
# 0  https://www.yelp.com/user_details?userid=MgHxF...  twenty seven steps
# 1  https://www.yelp.com/user_details?userid=Z583n...  twenty seven steps
# 2  https://www.yelp.com/user_details?userid=PqR0K...  twenty seven steps
# 3  https://www.yelp.com/user_details?userid=IaX6k...  twenty seven steps
# 4  https://www.yelp.com/user_details?userid=ODxAj...  twenty seven steps
#
#   price       categories                                               link
# 0    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 1    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 2    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 3    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...
# 4    $$  Modern European  https://www.yelp.com/biz/twenty-seven-steps-ch...

# %%
chc_reviews_df.to_csv("christchurch-yelp-reviews.csv", index=False)
print("Saved final cleaned file: christchurch-yelp-reviews.csv")
# Out:
# Saved final cleaned file: christchurch-yelp-reviews.csv

# %%
# Save as Parquet
chc_reviews_df.to_parquet("data/chc-yelp-reviews-v2/christchurch-yelp-reviews.parquet", index=False)
print("Saved final cleaned file: christchurch-yelp-reviews.parquet")
# Out:
# Saved final cleaned file: christchurch-yelp-reviews.parquet

# %%
import json

# Ensure 'date' is a string
chc_reviews_df["date"] = chc_reviews_df["date"].astype(str)

# Group all reviews by restaurant
grouped_data = []

for title, group in chc_reviews_df.groupby("title"):
    record = {
        "restaurant": title,
        "place_id": group["place_id"].iloc[0],
        "reviews": group[[
            "user", "rating", "date", "text", "review_type",
            "user_address", "useful", "cool", "funny"
        ]].to_dict(orient="records")
    }
    grouped_data.append(record)

# Save as pretty JSON
with open("chc-yelp-reviews.json", "w", encoding="utf-8") as f:
    json.dump(grouped_data, f, ensure_ascii=False, indent=4)

print("Exported grouped JSON to 'chc-yelp-reviews.json'")
# Out:
# Exported grouped JSON to 'chc-yelp-reviews.json'

# %%
with open("chc-yelp-reviews.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Print total restaurants and first few entries
print(f"Total restaurants: {len(data)}\n")
print(json.dumps(data[:2], indent=4, ensure_ascii=False))
# Out:
# Total restaurants: 186
#
# [
#     {
#         "restaurant": "5th street",
#         "place_id": "Busy8uaGSr4xVTDK64KCcg",
#         "reviews": [
#             {
#                 "user": "Andy M.",
#                 "rating": 5,
#                 "date": "2024-10-24 07:32:01",
#                 "text": "One of the finest farm to table restaurants I've ever been to in the world. The head chef is passionate about his craft, great staff, service and ambience. Don't miss this gem!\nUpdate. So good I came back 2 days later !",
#                 "review_type": "recommended",
#                 "user_address": "Cincinnati, OH",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "Mark C.",
#                 "rating": 5,
#                 "date": "2024-04-19 20:19:21",
#                 "text": "What a treat in Christchurch. Off the beaten path. In an  industrial area. But inside you feel like you're in a tropical garden.\nThe food was excellent from start to finish. The lamb shank was other worldly. We tried a straticalla appetizer that was super. Fish croquettes were very good. \nNice bar with good wine list.\nWe shared the chef table and our chef/owner/server Samson was sooo entertaining!\nMy wife and I both loved this restaurant. \nAt the top of our favorite restaurants on our month long vacation to New Zealand and Australia.\nGet a res if your anywhere nearby.",
#                 "review_type": "recommended",
#                 "user_address": "Sharpsburg, PA",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "Monica L.",
#                 "rating": 5,
#                 "date": "2024-02-15 02:45:19",
#                 "text": "Very elegant and nice warm wooden interior, love all the plants and natural light! \n\nService was also great, waiter explained the menu and was very attentive in answering questions and refilling water\n\nPlating of food was beautiful! Great flavor profiles and ingredients felt high quality. The saffron cauliflower was perfectly warm and hearty. The cucumber salad was creamy and refreshing. And the lamb shoulder was sooo super tender, no knife even needed! The whipped labneh cream and zaatar flavoring paired so well w the lamb. Great meal, felt full and very satisfied after :)",
#                 "review_type": "recommended",
#                 "user_address": "Boston, MA",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "J T.",
#                 "rating": 5,
#                 "date": "2023-11-23 07:11:10",
#                 "text": "Best meal in NZ so far!    Everything we had was amazing and the service was fantastic.  The small plates were wagyu and stracciatella with bread, then moved on to the medium plates of asparagus with ham and then the tomato salad, and for the finale we had the lamb shoulder. All were top notch.  This is a must for anyone, but particularly for visitors looking for a great meal.",
#                 "review_type": "recommended",
#                 "user_address": "Rockwall, TX",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "Colton S.",
#                 "rating": 5,
#                 "date": "2023-03-09 06:40:09",
#                 "text": "Holy Sh*t this place rocked our world. We were only in Christchurch for a few hours before our flight back to Auckland and stopped here based on reviews. It. Was. Amazing. Best meal of the two week trip through Auckland, Queenstown, Rotorua, and Wellington. We've been to several of the \"Best Of...\" restaurants on this trip and there was only one other place (Charley Noble in Wellington) that was even close to as good as 5th street. We sat at the Chefs Table which made everything even better because Samson served us and he's one of the co-owners and lead chefs crafting the menu. Such a great dude, and his team is really doin the Lord's work over here. We had four cocktails (Mezcal Milkpunch, Spritz 2x, and the Stirred). The lead bartender is a blast as well and is coming up with some truly delicious, refreshing drinks on this ever-changing menu (so I hear). We got the broccolini, the beef with pickled ginger, potatoes, and the true gem of the meal = the lamb shoulder. The lamb melts in your mouth. Do not hesitate for a second to order it even if you're not a big red meat eater! I'm sitting here at the airport not an hour removed from dinner and I had to write this review because of the lamb AND the quality of service. Props to Samson, Chris, and the third mustached musketeer / co-owner for creating such a memorable dining experience. And if you're wondering, \"is this guy still buzzed from the drinks he ordered at dinner?\" The answer is \"Hell yes. I couldn't NOT order a 4th cocktail.\" Anyway, cheers to the 5th street team for the beautiful work you're doing. We'll think of you every time we talk about our trip to NZ and/or use the chili oil we bought on our way out.",
#                 "review_type": "recommended",
#                 "user_address": "Pasadena, CA",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "Jae V.",
#                 "rating": 5,
#                 "date": "2019-12-08 22:52:27",
#                 "text": "Location \n\nNear city centre with hotels and other restaurants near by.\n\nFood  \n\nInternational and inspired.  There is Asian, American and more represented on the menu. There are small, medium, and large plates to choose from.  We ordered pan fried shrimp, broccolini and kale, crispy potatoes, the tomahawk steak, and the risotto. We enjoyed all of it. We also had some sort of deconstructed lemon pie with a divine lemon ice cream.\n\nAtmosphere/decor  \n\nThe space is very green in more ways than one.  It's literally filled with plants and green decorations.  Beautiful lighting.  Hipster vibe.\n\nService  \n\nNo issues here.  We sat at the 'chef's table' which is really 4 bar seats in front of the kitchen. This made the experience for us! The sous chef spoke with us and  answered questions all while doing his job of cooking.  He also let us try the zucchini fritters on the house. Outstanding gesture! He takes all your orders personally and you can see the chefs cooking your meal and then it is present directly to you.\n\nRecommendation \n\nYup, eat here.",
#                 "review_type": "recommended",
#                 "user_address": "Atlanta, GA",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             }
#         ]
#     },
#     {
#         "restaurant": "abalone thai restaurant",
#         "place_id": "Bonsa2BwNhdqFWVmrn1Rag",
#         "reviews": [
#             {
#                 "user": "Jim P.",
#                 "rating": 3,
#                 "date": "2014-12-15 05:15:10",
#                 "text": "Good service decent prices, food is just okay.\nWe had Massaman curry beef\nPad Thai seafood (really fishy tasting... I mean really strong, and I like fish, and fish sauce. Usually.\n\nTom Kha soup (one of my favorites) was very bland.\n\nMoney Bags were good.\n\nOthers have given this place good reviews and it's probably worth another try.",
#                 "review_type": "recommended",
#                 "user_address": "Port Townsend, WA",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "Joshua N.",
#                 "rating": 5,
#                 "date": "2014-03-21 18:07:46",
#                 "text": "After a two week long vacation in New Zealand, we had the good fortune to find this restaurant on our last night in New Zealand.  Excellent menu choices, very friendly staff, and good food!  My wife said it was the best meal she'd had in New Zealand.  We had walked about 2 miles from our hotel to get there, so when we finished dinner, we asked them to call a taxi for us...Five minutes later, the owner of the restaurant drove up and took us back to the hotel (couldn't have been more friendly).  Where else in the world do you get this type of service?  The restaurant is tucked back in a little strip mall, but do yourself a favor and take the time to look for it!",
#                 "review_type": "recommended",
#                 "user_address": "Gresham, OR",
#                 "useful": 2,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "Nathan L.",
#                 "rating": 4,
#                 "date": "2013-10-14 07:00:21",
#                 "text": "Prompt service, great food and BYO. Very friendly staff. Set menu was great. Good selection and very tasty. Also in the Entertainment book if you have one! Busy but great atmosphere.",
#                 "review_type": "recommended",
#                 "user_address": "London, United Kingdom",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             },
#             {
#                 "user": "Michael O.",
#                 "rating": 4,
#                 "date": "2013-08-20 06:21:59",
#                 "text": "Very good Thai food at reasonable prices. The sizzling hot plate meals are excellent, particularly the award winning Lamb. Worth a visit.",
#                 "review_type": "recommended",
#                 "user_address": "Canterbury, New Zealand",
#                 "useful": 0,
#                 "cool": 0,
#                 "funny": 0
#             }
#         ]
#     }
# ]
