# %% [markdown]
# # 1. Discover all restaurants in Christchurch

# %% [markdown]
# ## 1.1 Test with small subset

# %%
import os
import requests
import pandas as pd

# %%
SERPAPI_API_KEY = os.getenv("SERPAPI_API_KEY")

# %%
endpoint = "https://serpapi.com/search.json"
params = {
    "engine": "google_maps",
    "q": "restaurants in Christchurch, New Zealand",
    "hl": "en",
    "api_key": SERPAPI_API_KEY,
    "num": 4,
}

# %%
response = requests.get(endpoint, params=params, timeout=30)
print("Status:", response.status_code)
# Out:
# Status: 200

# %%
data = response.json()

# %%
print("Top-level keys:", list(data.keys()))
# Out:
# Top-level keys: ['search_metadata', 'search_parameters', 'search_information', 'local_results']

# %%
results = data.get("local_results") or data.get("places") or data.get("results") or []
print(f"Fetched {len(results)} restaurants")
# Out:
# Fetched 20 restaurants

# %%
# Normalize to DataFrame
rows = []
for r in results[:20]:  # Explicit limit of 4, just in case
    gps = r.get("gps_coordinates", {})
    rows.append({
        "title": r.get("title"),
        "address": r.get("address"),
        "rating": r.get("rating"),
        "reviews_count": r.get("reviews_count") or r.get("reviews"),
        "type": r.get("type") or r.get("category"),
        "lat": gps.get("latitude"),
        "lon": gps.get("longitude"),
        "place_id": r.get("place_id"),
        "link": r.get("link") or r.get("place_link"),
    })

# %%
df = pd.DataFrame(rows)
df.head(20)
# Out:
#                                     title  \
# 0         Fiddlesticks Restaurant and Bar
# 1                      Little High Eatery
# 2                            Casa Publica
# 3                           King of Snake
# 4                      Twenty Seven Steps
# 5                              5th Street
# 6                         The Monday Room
# 7                           Bloody Mary's
# 8                                Dux Dine
# 9                        Inati restaurant
# 10                             Zodiac Bar
# 11                        Strawberry Fare
# 12                  Castro's Christchurch
# 13                           Soul Quarter
# 14                 O.G.B Bar & Restaurant
# 15  Rangoon Ruby Christchurch New Zealand
# 16                               Bar Yoku
# 17                             Mexicano's
# 18                              Amazonita
# 19                  Gatherings Restaurant
#
#                                               address  rating  reviews_count  \
# 0   Corner of Worcester Boulevard &, Montreal Stre...     4.5           2151
# 1   255 Saint Asaph Street, Christchurch Central C...     4.6           4772
# 2   180 Armagh Street, Christchurch Central City, ...     4.5           1918
# 3   Level 1/79 Cashel Street, Christchurch Central...     4.7           1982
# 4   Christchurch Central City, Christchurch 8011, ...     4.7           1117
# 5   5 Elgin Street, Sydenham, Christchurch 8023, N...     4.8           1103
# 6   161 High Street, Christchurch Central City, Ch...     4.7            577
# 7   30 Latimer Square, Christchurch Central City, ...     4.4           1709
# 8   28 Riccarton Road, Riccarton, Christchurch 801...     4.3           1495
# 9   48 Hereford Street, Christchurch Central City,...     4.6            411
# 10  134 Oxford Terrace, Christchurch Central City,...     4.6            559
# 11  15 Bealey Avenue, Merivale, Christchurch 8013,...     4.5           1680
# 12  100 Oxford Terrace, Christchurch Central City,...     4.3            772
# 13  219 High Street, Christchurch Central City, Ch...     4.5            294
# 14  28 Cathedral Square, Christchurch Central City...     4.6           1522
# 15  819 Colombo Street, Christchurch Central City,...     4.7            401
# 16  The Welder 20 Welles Street, Christchurch Cent...     4.8            955
# 17  131 Victoria Street, Christchurch Central City...     4.4           1766
# 18  Level One/126 Oxford Terrace, Christchurch Cen...     4.4           1129
# 19  5/2 Papanui Road, Merivale, Christchurch 8014,...     4.7            274
#
#                           type        lat         lon  \
# 0                   Restaurant -43.531130  172.630861
# 1                   Restaurant -43.535783  172.640930
# 2                   Restaurant -43.528870  172.638831
# 3                   Restaurant -43.532998  172.634066
# 4   Modern European restaurant -43.529415  172.638797
# 5                   Restaurant -43.545705  172.633856
# 6                   Restaurant -43.535844  172.641503
# 7                  Bar & grill -43.530631  172.643532
# 8                   Restaurant -43.528824  172.608232
# 9                   Restaurant -43.532150  172.632474
# 10                  Restaurant -43.532544  172.634058
# 11                  Restaurant -43.520461  172.626163
# 12                  Restaurant -43.534109  172.633729
# 13                  Restaurant -43.534047  172.639109
# 14                  Restaurant -43.531140  172.638029
# 15          Burmese restaurant -43.525641  172.636480
# 16         Japanese restaurant -43.537171  172.637756
# 17          Mexican restaurant -43.523376  172.629649
# 18                  Restaurant -43.532700  172.634139
# 19                  Restaurant -43.520577  172.628026
#
#                        place_id  link
# 0   ChIJyWuAlj6KMW0RJoEgBUNTpUY  None
# 1   ChIJ715FmhiKMW0R3l3ead1fVoc  None
# 2   ChIJ-VFSwCSKMW0Ravlz2-ykUCk  None
# 3   ChIJ9Sy6qDeKMW0R9VU19Pt-Tms  None
# 4   ChIJOWVyvSSKMW0R9VyXIwcit6A  None
# 5   ChIJtWlYrdWLMW0RtM_yFEBNmyI  None
# 6   ChIJNeR2qx6KMW0RpEdCD-4OEiQ  None
# 7   ChIJs1hbUiGKMW0RpEbiAchchGY  None
# 8   ChIJUb-b0F6KMW0RfpU-5ucKrz0  None
# 9   ChIJeS560z2KMW0Rkq0hCGpDF54  None
# 10  ChIJy0RhpR6LMW0RAWtTycZo78I  None
# 11  ChIJ8ad5mDqKMW0R1b6AD2BFqxg  None
# 12  ChIJceHaNeSLMW0RXUMNXH-egNw  None
# 13  ChIJ_0uGn2aLMW0RvJCrBHK85wE  None
# 14  ChIJ037kSCOKMW0RnFE4xqLeJMA  None
# 15  ChIJVRQEozqKMW0RVoZt5_r0g18  None
# 16  ChIJJ73NCMCLMW0RH4F6p_2JiLI  None
# 17  ChIJf187CjeKMW0RU_PA5W7IAoM  None
# 18  ChIJkbAbsD2KMW0RGCid_gj5Et0  None
# 19  ChIJJ0o8EjaKMW0RmJf3YuwgSEI  None

# %% [markdown]
# ## 1.2 READ THE CHC RESTAURANT PLACE ID DATASET

# %%
chc_restaurant = pd.read_csv("data/google-data/chc_google_places.csv")

chc_restaurant.head()
# Out:
#                       place_id                                data_id  \
# 0  ChIJ715FmhiKMW0R3l3ead1fVoc  0x6d318a189a455eef:0x87565fdd69de5dde
# 1  ChIJS9eZVjyKMW0R-LmTqSCw23U  0x6d318a3c5699d74b:0x75dbb020a993b9f8
# 2  ChIJ78Zg4HOLMW0Rbh5zuS_Mdc8  0x6d318b73e060c6ef:0xcf75cc2fb9731e6e
# 3  ChIJBV_ck_SKMW0RgIWgFz4arWs  0x6d318af493dc5f05:0x6bad1a3e17a08580
# 4  ChIJ9XtNIxqKMW0Rm9tQ--IE0bc  0x6d318a1a234d7bf5:0xb7d104e2fb50db9b
#
#                            title  \
# 0             Little High Eatery
# 1               The Rockpool Bar
# 2                     Smokey T's
# 3  Drexel's Breakfast Restaurant
# 4           Denny’s Christchurch
#
#                                              address        lat         lon  \
# 0  255 Saint Asaph Street, Christchurch Central C... -43.535783  172.640930
# 1  85 Hereford Street, Christchurch Central City,... -43.531927  172.634590
# 2  314 Cashel Street, Christchurch Central City, ... -43.533386  172.648111
# 3  Rotherham Street, Riccarton, Christchurch 8041... -43.531336  172.600797
# 4  382 Moorhouse Avenue, Christchurch Central Cit... -43.540269  172.639198
#
#                    type  rating  reviews_count  url  \
# 0            Restaurant     4.6         4772.0  NaN
# 1           Bar & grill     4.2         2757.0  NaN
# 2   Barbecue restaurant     4.8         2423.0  NaN
# 3  Breakfast restaurant     4.5         2415.0  NaN
# 4            Restaurant     3.7         2328.0  NaN
#
#                                search_query  start_offset  \
# 0  restaurants in Christchurch, New Zealand             0
# 1         bars in Christchurch, New Zealand             0
# 2  restaurants in Christchurch, New Zealand            60
# 3  restaurants in Christchurch, New Zealand            40
# 4  restaurants in Christchurch, New Zealand           100
#
#           serpapi_search_id                   unique_key
# 0  691504b4f5c2f87c4863c1f7  ChIJ715FmhiKMW0R3l3ead1fVoc
# 1  6915061fcc56d3342f0925f9  ChIJS9eZVjyKMW0R-LmTqSCw23U
# 2  691504c127133264efad5ce1  ChIJ78Zg4HOLMW0Rbh5zuS_Mdc8
# 3  691504bc05bb59bb59ebd5b1  ChIJBV_ck_SKMW0RgIWgFz4arWs
# 4  691504c89c231269bd88432f  ChIJ9XtNIxqKMW0Rm9tQ--IE0bc

# %%
chc_restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   place_id           551 non-null    object
#  1   data_id            551 non-null    object
#  2   title              551 non-null    object
#  3   address            551 non-null    object
#  4   lat                551 non-null    float64
#  5   lon                551 non-null    float64
#  6   type               551 non-null    object
#  7   rating             549 non-null    float64
#  8   reviews_count      549 non-null    float64
#  9   url                0 non-null      float64
#  10  search_query       551 non-null    object
#  11  start_offset       551 non-null    int64
#  12  serpapi_search_id  551 non-null    object
#  13  unique_key         551 non-null    object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 60.4+ KB

# %%
chc_restaurant.isnull().sum()
# Out:
# place_id               0
# data_id                0
# title                  0
# address                0
# lat                    0
# lon                    0
# type                   0
# rating                 2
# reviews_count          2
# url                  551
# search_query           0
# start_offset           0
# serpapi_search_id      0
# unique_key             0
# dtype: int64

# %%
chc_restaurant[chc_restaurant["reviews_count"].isnull()]
# Out:
#                         place_id                                data_id  \
# 549  ChIJF1NhCJCLMW0RvyL-l-jBhJY  0x6d318b9008615317:0x9684c1e897fe22bf
# 550  ChIJi8Uaw7-LMW0R9t5QmJr_GGU  0x6d318bbfc31ac58b:0x6518ff9a9850def6
#
#                                title  \
# 549  stpierre stores in christchurch
# 550                          Zayed’s
#
#                                                address        lat         lon  \
# 549            Papanui, Christchurch 8053, New Zealand -43.490655  172.603093
# 550  88 Cashel Street, Christchurch Central City, C... -43.533252  172.634303
#
#                     type  rating  reviews_count  url  \
# 549  Japanese restaurant     NaN            NaN  NaN
# 550    Indian restaurant     NaN            NaN  NaN
#
#                                          search_query  start_offset  \
# 549  japanese restaurant in Christchurch, New Zealand            80
# 550    indian restaurant in Christchurch, New Zealand            60
#
#             serpapi_search_id                   unique_key
# 549  691506d313f4b687fe830e7b  ChIJF1NhCJCLMW0RvyL-l-jBhJY
# 550  691506e7556ce3627c5e66e1  ChIJi8Uaw7-LMW0R9t5QmJr_GGU

# %%
bad_place_ids = [
    "ChIJF1NhCJCLMW0RvyL-l-jBhJY",
    "ChIJi8Uaw7-LMW0R9t5QmJr_GGU"
]

# Filter them out
chc_restaurant_clean = chc_restaurant[~chc_restaurant["place_id"].isin(bad_place_ids)].copy()

len_before = len(chc_restaurant)
len_after = len(chc_restaurant_clean)

print(f"Removed {len_before - len_after} restaurants.")
print(f"Remaining restaurants: {len_after}")
# Out:
# Removed 2 restaurants.
# Remaining restaurants: 549

# %%
chc_restaurant = chc_restaurant_clean

# %%
chc_restaurant.isnull().sum()
# Out:
# place_id               0
# data_id                0
# title                  0
# address                0
# lat                    0
# lon                    0
# type                   0
# rating                 0
# reviews_count          0
# url                  549
# search_query           0
# start_offset           0
# serpapi_search_id      0
# unique_key             0
# dtype: int64

# %%
chc_restaurant.to_csv("data/google-data/chc_google_places_v1.csv", index=False)

# %%
chc_restaurant["reviews_count"].describe()
# Out:
# count     549.000000
# mean      471.593807
# std       514.763436
# min         1.000000
# 25%       141.000000
# 50%       295.000000
# 75%       606.000000
# max      4772.000000
# Name: reviews_count, dtype: float64

# %%
# How many unique restaurants in each search query
summary = (
    chc_restaurant
    .groupby("search_query")
    .agg(unique_restaurants=("unique_key", "nunique"))
    .sort_values("unique_restaurants", ascending=False)
)

print(summary)
# Out:
#                                                     unique_restaurants
# search_query
# bars in Christchurch, New Zealand                                  102
# japanese restaurant in Christchurch, New Zealand                    86
# chinese restaurant in Christchurch, New Zealand                     84
# indian restaurant in Christchurch, New Zealand                      79
# thai restaurant in Christchurch, New Zealand                        72
# food in Christchurch, New Zealand                                   60
# restaurants in Christchurch, New Zealand                            44
# vietnamese restaurant in Christchurch, New Zealand                  24

# %% [markdown]
# * each restaurant may appear under multiple queries, we cannot simply sum the reviews_count column directly

# %%
# Sum the total reviews count
total_reviews = (
    chc_restaurant
    .groupby("unique_key")["reviews_count"]
    .max()      # or first(), reviews_count is the same for duplicate rows
    .sum()
)

print("Total review count:", int(total_reviews))
# Out:
# Total review count: 258905

# %%
unique_restaurants = (
    chc_restaurant
    .groupby("unique_key")
    .agg({
        "title": "first",
        "reviews_count": "max"
    })
)

unique_restaurants.head(20)
# Out:
#                                                   title  reviews_count
# unique_key
# ChIJ---ig4OJMW0RicyQ-MSYXWc          Sun Ning Takeaways          277.0
# ChIJ--CTb9CJMW0RRB_3kl9puIE    Ferry Indians Restaurant          373.0
# ChIJ-3bod9qLMW0R4okkg02foAU        Tanoshi Christchurch          749.0
# ChIJ-RznvSSKMW0R1zzUrxn2Ix8        The Nook Thai Eatery          262.0
# ChIJ-VFSwCSKMW0Ravlz2-ykUCk                Casa Publica         1918.0
# ChIJ-W_zzA2LMW0RrQJtBIQEgJU                 Sushi Court           18.0
# ChIJ-fT1P8SPMW0RJrXe3Cn6eQ0  Samairaz Indian Restaurant          711.0
# ChIJ-xKFcWmLMW0RM_kBgFMJQQQ             Tavern Harewood         1689.0
# ChIJ-zvZccf0MW0R0IJMWE_QzbA       Little India Spitfire          494.0
# ChIJ0-A9udeLMW0R8IyGHtEZNIY                   Bollyfood          172.0
# ChIJ0-CXZoKJMW0Rb0YwhvIpfWY        The Bombay Brasserie          372.0
# ChIJ01SLHTqKMW0RKPTXKepNnnY     Kum Pun Thai Restaurant          561.0
# ChIJ037kSCOKMW0RnFE4xqLeJMA      O.G.B Bar & Restaurant         1522.0
# ChIJ04YcsvWKMW0R0ibjdhRno3M         The Craic Irish Bar          521.0
# ChIJ05dyg9KLMW0RaxcoXl4E0uo    Tomi Japanese Restaurant          354.0
# ChIJ07sqgtKLMW0R-rrB764Z_G0         Sema's Thai Cuisine          265.0
# ChIJ0QuLvseLMW0RLsXhT91gH8Y                     Bar 185           96.0
# ChIJ0XvZt2D1MW0RG-tmQHkG8ZU       Chang Thai Restaurant          292.0
# ChIJ0ZyDZHuKMW0R6a9C5vOS-jM  The Pedal Pusher Addington         1007.0
# ChIJ0dIc46KJMW0Rz8MsEyUd760               Longtail Thai          178.0

# %% [markdown]
# - 551 unique restaurants accross CHC has been scrapped
# - There are: 258905 reviews in total

# %% [markdown]
# #### Identify The Cutoff To Reduce Quota

# %%
# total reviewa by restaurants
total_reviews_by_restaurants = chc_restaurant[['unique_key', 'reviews_count']]


total_reviews_by_restaurants['estimated_reviews_last_1_year'] = total_reviews_by_restaurants['reviews_count'] * 0.15
total_reviews_by_restaurants['estimated_reviews_last_2_years'] = total_reviews_by_restaurants['reviews_count'] * 0.30
total_reviews_by_restaurants['estimated_reviews_last_3_years'] = total_reviews_by_restaurants['reviews_count'] * 0.45


estimated_cost_1_year = total_reviews_by_restaurants['estimated_reviews_last_1_year'].sum() / 10
estimated_cost_2_years = total_reviews_by_restaurants['estimated_reviews_last_2_years'].sum() / 10
estimated_cost_3_years = total_reviews_by_restaurants['estimated_reviews_last_3_years'].sum() / 10

print("Requests for 1-year cutoff:", estimated_cost_1_year)
print("Requests for 2-year cutoff:", estimated_cost_2_years)
print("Requests for 3-year cutoff:", estimated_cost_3_years)
# Out:
# Requests for 1-year cutoff: 3883.5749999999994
# Requests for 2-year cutoff: 7767.149999999999
# Requests for 3-year cutoff: 11650.725
# /var/folders/qw/mns0z74d3t1_nqjy7zgm7mkw0000gn/T/ipykernel_77265/1505465254.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_reviews_by_restaurants['estimated_reviews_last_1_year'] = total_reviews_by_restaurants['reviews_count'] * 0.15
# /var/folders/qw/mns0z74d3t1_nqjy7zgm7mkw0000gn/T/ipykernel_77265/1505465254.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_reviews_by_restaurants['estimated_reviews_last_2_years'] = total_reviews_by_restaurants['reviews_count'] * 0.30
# /var/folders/qw/mns0z74d3t1_nqjy7zgm7mkw0000gn/T/ipykernel_77265/1505465254.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_reviews_by_restaurants['estimated_reviews_last_3_years'] = total_reviews_by_restaurants['reviews_count'] * 0.45

# %%
# Delete the search query "bars in Christchurch, New Zealand" as it obtain a highest restaurants
# Count before removal
print("Total restaurants before:", len(chc_restaurant))

# Define the search query to remove
REMOVE_QUERY = "bars in Christchurch, New Zealand"

chc_restaurants_without_bar = chc_restaurant[chc_restaurant["search_query"] != REMOVE_QUERY]

# Count after remove
print("Total restaurants after:", len(chc_restaurants_without_bar))
# Out:
# Total restaurants before: 551
# Total restaurants after: 449

# %%
# How many unique restaurants in each search query
summary = (
    chc_restaurants_without_bar
    .groupby("search_query")
    .agg(unique_restaurants=("unique_key", "nunique"))
    .sort_values("unique_restaurants", ascending=False)
)

print(summary)
# Out:
#                                                     unique_restaurants
# search_query
# japanese restaurant in Christchurch, New Zealand                    86
# chinese restaurant in Christchurch, New Zealand                     84
# indian restaurant in Christchurch, New Zealand                      79
# thai restaurant in Christchurch, New Zealand                        72
# food in Christchurch, New Zealand                                   60
# restaurants in Christchurch, New Zealand                            44
# vietnamese restaurant in Christchurch, New Zealand                  24

# %%
chc_restaurants_without_bar['reviews_count'].sum()
# Out:
# np.float64(198044.0)

# %%
# Define the search query to remove
REMOVE_QUERY = "restaurants in Christchurch, New Zealand"

chc_restaurants_without_restaurants = chc_restaurants_without_bar[chc_restaurants_without_bar["search_query"] != REMOVE_QUERY]

# Count after remove
print("Total restaurants after:", len(chc_restaurants_without_restaurants))
# Out:
# Total restaurants after: 405

# %%
chc_restaurants_without_restaurants['reviews_count'].sum()
# Out:
# np.float64(153918.0)

# %% [markdown]
# # 2. Scrape Google Reviews Data

# %% [markdown]
# After estimate the number of requests for each of 551 restaurants and there reviews counts is extremely large.
#
# So I decide to scrape only 10 latest reviews (1st page) of each restaurants only.
#
# So in total there will be 551 requests.

# %% [markdown]
# ## 2.1 Test with only one specific restaurant first

# %%
# --- Select only "BB Vietnamese Street Food" ---
target_name = "BB Vietnamese Street Food"

row = chc_restaurant[chc_restaurant["title"] == target_name]

if row.empty:
    raise ValueError(f"Restaurant '{target_name}' not found in chc_restaurant dataset")

place_id = row.iloc[0]["place_id"]
data_id = row.iloc[0]["data_id"]

print("Selected restaurant:")
row[["title", "place_id", "data_id", "reviews_count"]]
# Out:
# Selected restaurant:
#                          title                     place_id  \
# 409  BB Vietnamese Street Food  ChIJzZunKzCLMW0RIrdqXcaoYLo
#
#                                    data_id  reviews_count
# 409  0x6d318b302ba79bcd:0xba60a8c65d6ab722          142.0

# %%
# SerpAPI Key
SERPAPI_API_KEY = os.getenv("SERPAPI_API_KEY")
if not SERPAPI_API_KEY:
    raise RuntimeError("Please set SERPAPI_API_KEY environment variable")


# --- SerpAPI endpoint ---
SERPAPI_ENDPOINT = "https://serpapi.com/search.json"

# --- Build request ---
params = {
    "engine": "google_maps_reviews",
    "api_key": SERPAPI_API_KEY,
    "place_id": place_id,     # either place_id or data_id works
    "hl": "en",
    "sort_by": "newestFirst", # important: newest 10 reviews only!
    # WARNING: num cannot be used on the first page per SerpAPI rules,
    # so we will always get 8-10 reviews automatically.
}

print("\nRequesting newest reviews…")

r = requests.get(SERPAPI_ENDPOINT, params=params)
print("HTTP Status:", r.status_code)

data = r.json()
# Out:
# Requesting newest reviews…
# HTTP Status: 200

# %%
# --- Extract reviews ---
reviews = data.get("reviews", [])

print(f"\n🔍 Retrieved {len(reviews)} newest reviews for: {target_name}\n")

# Pretty print first 1–2 reviews
for i, rv in enumerate(reviews[:2]):
    print(f"--- Review {i+1} ---")
    print("Rating:", rv.get("rating"))
    print("Date:", rv.get("date"))
    print("Text:", rv.get("snippet"))
    print()
# Out:
# 🔍 Retrieved 8 newest reviews for: BB Vietnamese Street Food
#
# --- Review 1 ---
# Rating: 5.0
# Date: a week ago
# Text: Really good beef stew,friendly staff, best service in Christchuch i have ever tried
#
# --- Review 2 ---
# Rating: 4.0
# Date: 2 weeks ago
# Text: Taste of food was pretty good. The shaking beefs flavour was pretty on par with a good one however the beef wasn't as tender as I have experienced elsewhere but none the less not bad at all. Bahn mi was very fresh and delicious and would highly recommend. A word of advice tho...make sure to either order in advance or avoid during lunch as the place gets pretty swamped making wait times super long as it is only a small kitchen.

# %%
# --- Convert to DataFrame ---
df_reviews = pd.DataFrame(reviews)

print("\nDataFrame columns:", df_reviews.columns.tolist())
df_reviews.head(20)
# Out:
# DataFrame columns: ['link', 'rating', 'date', 'iso_date', 'iso_date_of_last_edit', 'images', 'source', 'review_id', 'user', 'snippet', 'extracted_snippet', 'details', 'response']
#                                                 link  rating         date  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...     5.0   a week ago
# 1  https://www.google.com/maps/reviews/data=!4m8!...     4.0  2 weeks ago
# 2  https://www.google.com/maps/reviews/data=!4m8!...     5.0  2 weeks ago
# 3  https://www.google.com/maps/reviews/data=!4m8!...     5.0  3 weeks ago
# 4  https://www.google.com/maps/reviews/data=!4m8!...     5.0  4 weeks ago
# 5  https://www.google.com/maps/reviews/data=!4m8!...     5.0  4 weeks ago
# 6  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a month ago
# 7  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a month ago
#
#                iso_date iso_date_of_last_edit  \
# 0  2025-11-02T01:59:48Z  2025-11-02T01:59:48Z
# 1  2025-10-29T07:04:03Z  2025-10-29T07:08:00Z
# 2  2025-10-25T23:07:53Z  2025-10-25T23:07:53Z
# 3  2025-10-16T00:41:51Z  2025-10-16T00:41:51Z
# 4  2025-10-14T00:53:36Z  2025-10-14T00:53:36Z
# 5  2025-10-13T08:00:54Z  2025-10-13T08:00:54Z
# 6  2025-10-08T08:15:53Z  2025-10-08T08:15:53Z
# 7  2025-09-20T23:48:23Z  2025-09-20T23:48:23Z
#
#                                               images  source  \
# 0  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
# 1                                                NaN  Google
# 2  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
# 3  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
# 4  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
# 5                                                NaN  Google
# 6                                                NaN  Google
# 7                                                NaN  Google
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2t0c2EyTlNOV2cwYWtkS1...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2xkMFprazBVV28zVlVoQ0...
# 2  Ci9DQUlRQUNvZENodHljRjlvT25sRWFISnpXR2RuUWpsbl...
# 3  Ci9DQUlRQUNvZENodHljRjlvT21neWQwdFpWMGx4V1U5SE...
# 4  Ci9DQUlRQUNvZENodHljRjlvT2tocVYyeDBkV3BHTkU0dF...
# 5  Ci9DQUlRQUNvZENodHljRjlvT21OM1MwcDZSV1UzWXpoTU...
# 6  Ci9DQUlRQUNvZENodHljRjlvT2xkclp6ZG9iRmREUTFZMm...
# 7  Ci9DQUlRQUNvZENodHljRjlvT20wd1dYbHRaRTVwWTBoWG...
#
#                                                 user  \
# 0  {'name': 'My Le', 'link': 'https://www.google....
# 1  {'name': 'loading user', 'link': 'https://www....
# 2  {'name': '邢栀媛', 'link': 'https://www.google.co...
# 3  {'name': 'Usoalii Tafua', 'link': 'https://www...
# 4  {'name': 'พชร อุตตมโภคิน', 'link': 'https://ww...
# 5  {'name': 'kevin wu', 'link': 'https://www.goog...
# 6  {'name': 'Angie Tso', 'link': 'https://www.goo...
# 7  {'name': 'Thu Hue', 'link': 'https://www.googl...
#
#                                              snippet  \
# 0  Really good beef stew,friendly staff, best ser...
# 1  Taste of food was pretty good. The shaking bee...
# 2  The most delicious Vietnamese restaurant in Ch...
# 3                          Best food Best service 💯🏆
# 4                                               Good
# 5  Great food and good service. The food has grea...
# 6  Such a cute outdoor eatery with some of the BE...
# 7                                                NaN
#
#                                    extracted_snippet  \
# 0  {'original': 'Really good beef stew,friendly s...
# 1  {'original': 'Taste of food was pretty good. T...
# 2  {'original': 'The most delicious Vietnamese re...
# 3          {'original': 'Best food Best service 💯🏆'}
# 4                               {'original': 'Good'}
# 5  {'original': 'Great food and good service. The...
# 6  {'original': 'Such a cute outdoor eatery with ...
# 7                                                NaN
#
#                                              details  \
# 0  {'meal_type': 'Lunch', 'price_per_person': 'NZ...
# 1  {'price_per_person': 'NZ$20–30', 'food': 4, 's...
# 2  {'meal_type': 'Lunch', 'price_per_person': 'NZ...
# 3  {'meal_type': 'Dinner', 'price_per_person': 'N...
# 4                                                NaN
# 5  {'service': 5, 'price_per_person': 'NZ$20–30',...
# 6  {'meal_type': 'Lunch', 'price_per_person': 'NZ...
# 7  {'service': 5, 'meal_type': 'Lunch', 'price_pe...
#
#                                             response
# 0                                                NaN
# 1  {'date': '2 weeks ago', 'iso_date': '2025-10-2...
# 2  {'date': '2 weeks ago', 'iso_date': '2025-10-2...
# 3  {'date': '2 weeks ago', 'iso_date': '2025-10-2...
# 4  {'date': '2 weeks ago', 'iso_date': '2025-10-2...
# 5  {'date': '2 weeks ago', 'iso_date': '2025-10-2...
# 6  {'date': 'a month ago', 'iso_date': '2025-10-0...
# 7  {'date': 'a month ago', 'iso_date': '2025-09-2...

# %% [markdown]
# ## 2.1 Test with Pagenition

# %%
# Pick one restaurant by name
target_name = "BB Vietnamese Street Food"

restaurant_row = chc_restaurant[chc_restaurant["title"] == target_name].iloc[0]
place_id = restaurant_row["place_id"]

place_id
# Out:
# 'ChIJzZunKzCLMW0RIrdqXcaoYLo'

# %%
def scrape_reviews_page(place_id, next_page_token=None):
    params = {
        "engine": "google_maps_reviews",
        "api_key": SERPAPI_API_KEY,
        "hl": "en",
        "place_id": place_id,
        "sort_by": "newestFirst",
    }

    # Only add next_page_token for page 2
    if next_page_token:
        params["next_page_token"] = next_page_token

    r = requests.get(SERPAPI_ENDPOINT, params=params, timeout=60)
    if r.status_code != 200:
        print(r.text)
        raise RuntimeError(f"SerpAPI error {r.status_code}")

    data = r.json()
    return data

# %%
# --- Page 1 ---
page1 = scrape_reviews_page(place_id)
page1_reviews = page1.get("reviews", [])

print("Page 1 reviews:", len(page1_reviews))

# Get token for page 2
next_token = page1.get("serpapi_pagination", {}).get("next_page_token")
print("Next page token:", next_token)

# --- Page 2 ---
if next_token:
    page2 = scrape_reviews_page(place_id, next_page_token=next_token)
    page2_reviews = page2.get("reviews", [])
    print("Page 2 reviews:", len(page2_reviews))
else:
    page2_reviews = []
    print("No second page available.")
# Out:
# Page 1 reviews: 8
# Next page token: CAESY0NBRVFDQnBFUTJwRlNVRlNTWEJEWjI5QlVEY3lSMkZYWlV0RlZsOWZSV2hFYzNWTVJUZFBTSFppUWtwR2VWSndZMEZCUVVGQlIyZHVPUzE0WjBOYWNGbzBiMUpWV1VGRFNVRQ==
# Page 2 reviews: 10

# %%
all_reviews = page1_reviews + page2_reviews

df_reviews = pd.json_normalize(all_reviews)
df_reviews.head()
# Out:
#                                                 link  rating         date  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...     5.0   a week ago
# 1  https://www.google.com/maps/reviews/data=!4m8!...     4.0  2 weeks ago
# 2  https://www.google.com/maps/reviews/data=!4m8!...     5.0  2 weeks ago
# 3  https://www.google.com/maps/reviews/data=!4m8!...     5.0  3 weeks ago
# 4  https://www.google.com/maps/reviews/data=!4m8!...     5.0  4 weeks ago
#
#                iso_date iso_date_of_last_edit  \
# 0  2025-11-02T01:59:48Z  2025-11-02T01:59:48Z
# 1  2025-10-29T07:04:03Z  2025-10-29T07:08:00Z
# 2  2025-10-25T23:07:53Z  2025-10-25T23:07:53Z
# 3  2025-10-16T00:41:51Z  2025-10-16T00:41:51Z
# 4  2025-10-14T00:53:36Z  2025-10-14T00:53:36Z
#
#                                               images  source  \
# 0  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
# 1                                                NaN  Google
# 2  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
# 3  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
# 4  [https://lh3.googleusercontent.com/geougc-cs/A...  Google
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2t0c2EyTlNOV2cwYWtkS1...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2xkMFprazBVV28zVlVoQ0...
# 2  Ci9DQUlRQUNvZENodHljRjlvT25sRWFISnpXR2RuUWpsbl...
# 3  Ci9DQUlRQUNvZENodHljRjlvT21neWQwdFpWMGx4V1U5SE...
# 4  Ci9DQUlRQUNvZENodHljRjlvT2tocVYyeDBkV3BHTkU0dF...
#
#                                              snippet       user.name  ...  \
# 0  Really good beef stew,friendly staff, best ser...           My Le  ...
# 1  Taste of food was pretty good. The shaking bee...    loading user  ...
# 2  The most delicious Vietnamese restaurant in Ch...             邢栀媛  ...
# 3                          Best food Best service 💯🏆   Usoalii Tafua  ...
# 4                                               Good  พชร อุตตมโภคิน  ...
#
#    details.noise_level details.wait_time            details.group_size  \
# 0  Quiet, easy to talk           No wait                           NaN
# 1                  NaN               NaN                      Not sure
# 2       Moderate noise           No wait                           NaN
# 3                  NaN               NaN  Suitable for all group sizes
# 4                  NaN               NaN                           NaN
#
#                        details.seating_type  details.parking_space  \
# 0                                       NaN                    NaN
# 1  Outdoor patio / terrace, Counter seating               Not sure
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
#
#    response.date     response.iso_date response.iso_date_of_last_edit  \
# 0            NaN                   NaN                            NaN
# 1    2 weeks ago  2025-10-29T09:11:53Z           2025-10-29T09:11:53Z
# 2    2 weeks ago  2025-10-26T04:35:57Z           2025-10-26T04:35:57Z
# 3    2 weeks ago  2025-10-26T04:36:29Z           2025-10-26T04:36:29Z
# 4    2 weeks ago  2025-10-26T04:36:43Z           2025-10-26T04:36:43Z
#
#                                     response.snippet  \
# 0                                                NaN
# 1  Thank you so much for your kind review and ver...
# 2  Thank you so much for your lovely review, we r...
# 3                  Thank you so much for rating us 🥰
# 4                                Thank you so much 🥰
#
#                  response.extracted_snippet.original
# 0                                                NaN
# 1  Thank you so much for your kind review and ver...
# 2  Thank you so much for your lovely review, we r...
# 3                  Thank you so much for rating us 🥰
# 4                                Thank you so much 🥰
#
# [5 rows x 32 columns]

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   link                                 18 non-null     object
#  1   rating                               18 non-null     float64
#  2   date                                 18 non-null     object
#  3   iso_date                             18 non-null     object
#  4   iso_date_of_last_edit                18 non-null     object
#  5   images                               9 non-null      object
#  6   source                               18 non-null     object
#  7   review_id                            18 non-null     object
#  8   snippet                              17 non-null     object
#  9   user.name                            18 non-null     object
#  10  user.link                            18 non-null     object
#  11  user.contributor_id                  18 non-null     object
#  12  user.thumbnail                       18 non-null     object
#  13  user.local_guide                     18 non-null     bool
#  14  user.reviews                         18 non-null     int64
#  15  user.photos                          18 non-null     int64
#  16  extracted_snippet.original           17 non-null     object
#  17  details.meal_type                    9 non-null      object
#  18  details.price_per_person             13 non-null     object
#  19  details.food                         17 non-null     float64
#  20  details.service                      17 non-null     float64
#  21  details.atmosphere                   16 non-null     float64
#  22  details.noise_level                  3 non-null      object
#  23  details.wait_time                    7 non-null      object
#  24  details.group_size                   4 non-null      object
#  25  details.seating_type                 3 non-null      object
#  26  details.parking_space                1 non-null      object
#  27  response.date                        17 non-null     object
#  28  response.iso_date                    17 non-null     object
#  29  response.iso_date_of_last_edit       17 non-null     object
#  30  response.snippet                     17 non-null     object
#  31  response.extracted_snippet.original  17 non-null     object
# dtypes: bool(1), float64(4), int64(2), object(25)
# memory usage: 4.5+ KB

# %% [markdown]
# ## 2.2 READ THE CHC GOOGLE REVIEWS DATA

# %%
chc_google_reviews = pd.read_csv('data/google-data/google-reviews/chc_reviews.csv')

chc_google_reviews.head()
# Out:
#                                                 link  rating        date  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...     3.0  2 days ago
# 1  https://www.google.com/maps/reviews/data=!4m8!...     5.0  2 days ago
# 2  https://www.google.com/maps/reviews/data=!4m8!...     5.0  6 days ago
# 3  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
# 4  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
#
#                iso_date iso_date_of_last_edit  source  \
# 0  2025-11-11T00:25:07Z  2025-11-11T00:25:07Z  Google
# 1  2025-11-10T10:15:50Z  2025-11-10T10:15:50Z  Google
# 2  2025-11-06T18:56:05Z  2025-11-06T18:56:05Z  Google
# 3  2025-11-05T07:42:20Z  2025-11-05T07:42:20Z  Google
# 4  2025-11-05T07:14:08Z  2025-11-05T07:16:10Z  Google
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2xWMFpGYzRTemhuU0dKSl...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2w4NWQzbE1WRzFJY2w5bl...
# 2  Ci9DQUlRQUNvZENodHljRjlvT2xaSExTMHdUREJrZDFJd0...
# 3  Ci9DQUlRQUNvZENodHljRjlvT25KVmFXSm9kMkZ4Y1hkbE...
# 4  Ci9DQUlRQUNvZENodHljRjlvT205UFlVWm9hbHAyTkhGd2...
#
#                                              snippet  page_number  \
# 0  Thaifood hit n miss, bland mince meat rice, un...            1
# 1  Another one of those great finds....that you d...            1
# 2                          Super food and atmosphere            1
# 3  Food stalls.\nGot many things: from burger, bb...            1
# 4  Kao soi is delicious, very nice service kob kh...            1
#
#                       place_id  ... details.recommended_dishes  \
# 0  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 1  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 2  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 3  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 4  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
#
#   translated_details.kid_friendliness details.special_offers  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
#
#   details.food_drinks details.noteworthy_details  \
# 0                 NaN                        NaN
# 1                 NaN                        NaN
# 2                 NaN                        NaN
# 3                 NaN                        NaN
# 4                 NaN                        NaN
#
#    translated_details.vegetarian_options  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    response.extracted_snippet.translated  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   details.recommendation_for_vegetarians  details.vegetarian_offerings  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
#   translated_details.dietary_restrictions
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 58 columns]

# %%
chc_google_reviews['place_id'].nunique()
# Out:
# 549

# %% [markdown]
# ### Handle data with no text reviews

# %%
chc_google_reviews['place_id'].count()
# Out:
# np.int64(4374)

# %%
chc_google_reviews['snippet'].isna().sum()
# Out:
# np.int64(1095)

# %%
# show the data of missing reviews
missing_rows = chc_google_reviews[chc_google_reviews["snippet"].isna()]
missing_rows.head()
# Out:
#                                                  link  rating        date  \
# 5   https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
# 7   https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
# 10  https://www.google.com/maps/reviews/data=!4m8!...     3.0  4 days ago
# 14  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
# 15  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
#
#                 iso_date iso_date_of_last_edit  source  \
# 5   2025-11-05T00:19:29Z  2025-11-05T00:19:29Z  Google
# 7   2025-11-02T06:37:42Z  2025-11-02T06:37:42Z  Google
# 10  2025-11-09T02:30:27Z  2025-11-09T02:30:27Z  Google
# 14  2025-11-04T01:11:15Z  2025-11-04T01:11:15Z  Google
# 15  2025-11-04T00:05:23Z  2025-11-04T00:05:23Z  Google
#
#                                             review_id snippet  page_number  \
# 5   Ci9DQUlRQUNvZENodHljRjlvT2pCVVZGVkxTRmx1UzJOUF...     NaN            1
# 7   Ci9DQUlRQUNvZENodHljRjlvT25GVFpFNWpXR0Z1VGsxRm...     NaN            1
# 10  Ci9DQUlRQUNvZENodHljRjlvT21aSlJURm1aVlEzVWtSQl...     NaN            1
# 14  Ci9DQUlRQUNvZENodHljRjlvT21OSFNFVm1WMVZrUm0xT2...     NaN            1
# 15  Ci9DQUlRQUNvZENodHljRjlvT25GRFJuUkROMVUxZUVsem...     NaN            1
#
#                        place_id  ... details.recommended_dishes  \
# 5   ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 7   ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 10  ChIJS9eZVjyKMW0R-LmTqSCw23U  ...                        NaN
# 14  ChIJS9eZVjyKMW0R-LmTqSCw23U  ...                        NaN
# 15  ChIJS9eZVjyKMW0R-LmTqSCw23U  ...                        NaN
#
#    translated_details.kid_friendliness details.special_offers  \
# 5                                  NaN                    NaN
# 7                                  NaN                    NaN
# 10                                 NaN                    NaN
# 14                                 NaN                    NaN
# 15                                 NaN                    NaN
#
#    details.food_drinks details.noteworthy_details  \
# 5                  NaN                        NaN
# 7                  NaN                        NaN
# 10                 NaN                        NaN
# 14                 NaN                        NaN
# 15                 NaN                        NaN
#
#     translated_details.vegetarian_options  \
# 5                                     NaN
# 7                                     NaN
# 10                                    NaN
# 14                                    NaN
# 15                                    NaN
#
#     response.extracted_snippet.translated  \
# 5                                     NaN
# 7                                     NaN
# 10                                    NaN
# 14                                    NaN
# 15                                    NaN
#
#    details.recommendation_for_vegetarians  details.vegetarian_offerings  \
# 5                                     NaN                           NaN
# 7                                     NaN                           NaN
# 10                                    NaN                           NaN
# 14                                    NaN                           NaN
# 15                                    NaN                           NaN
#
#    translated_details.dietary_restrictions
# 5                                      NaN
# 7                                      NaN
# 10                                     NaN
# 14                                     NaN
# 15                                     NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# - There are total: 4374 reviews scraped
# - There are: 1095 reviews is empty
# - Delete the row with empty reviews

# %%
df_clean = chc_google_reviews.dropna(subset=["snippet"])

# %%
df_clean['place_id'].count()
# Out:
# np.int64(3279)

# %%
df_clean.to_csv('data/google-data/google-reviews/final/chc-google-reviews.csv')

# %%
df_clean.to_parquet('data/google-data/google-reviews/final/chc-google-reviews.parquet')

# %% [markdown]
# ## 2.3 Conver Json Structure

# %%
df_clean.head()
# Out:
#                                                 link  rating        date  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...     3.0  2 days ago
# 1  https://www.google.com/maps/reviews/data=!4m8!...     5.0  2 days ago
# 2  https://www.google.com/maps/reviews/data=!4m8!...     5.0  6 days ago
# 3  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
# 4  https://www.google.com/maps/reviews/data=!4m8!...     5.0  a week ago
#
#                iso_date iso_date_of_last_edit  source  \
# 0  2025-11-11T00:25:07Z  2025-11-11T00:25:07Z  Google
# 1  2025-11-10T10:15:50Z  2025-11-10T10:15:50Z  Google
# 2  2025-11-06T18:56:05Z  2025-11-06T18:56:05Z  Google
# 3  2025-11-05T07:42:20Z  2025-11-05T07:42:20Z  Google
# 4  2025-11-05T07:14:08Z  2025-11-05T07:16:10Z  Google
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2xWMFpGYzRTemhuU0dKSl...
# 1  Ci9DQUlRQUNvZENodHljRjlvT2w4NWQzbE1WRzFJY2w5bl...
# 2  Ci9DQUlRQUNvZENodHljRjlvT2xaSExTMHdUREJrZDFJd0...
# 3  Ci9DQUlRQUNvZENodHljRjlvT25KVmFXSm9kMkZ4Y1hkbE...
# 4  Ci9DQUlRQUNvZENodHljRjlvT205UFlVWm9hbHAyTkhGd2...
#
#                                              snippet  page_number  \
# 0  Thaifood hit n miss, bland mince meat rice, un...            1
# 1  Another one of those great finds....that you d...            1
# 2                          Super food and atmosphere            1
# 3  Food stalls.\nGot many things: from burger, bb...            1
# 4  Kao soi is delicious, very nice service kob kh...            1
#
#                       place_id  ... details.recommended_dishes  \
# 0  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 1  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 2  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 3  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
# 4  ChIJ715FmhiKMW0R3l3ead1fVoc  ...                        NaN
#
#   translated_details.kid_friendliness details.special_offers  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
#
#   details.food_drinks details.noteworthy_details  \
# 0                 NaN                        NaN
# 1                 NaN                        NaN
# 2                 NaN                        NaN
# 3                 NaN                        NaN
# 4                 NaN                        NaN
#
#    translated_details.vegetarian_options  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    response.extracted_snippet.translated  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   details.recommendation_for_vegetarians  details.vegetarian_offerings  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
#   translated_details.dietary_restrictions
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 58 columns]

# %%
restaurants = pd.read_csv("data/google-data/chc_google_places_v1.csv")
restaurants = restaurants[["place_id", "title"]].rename(columns={"title": "restaurant"})

df_clean = df_clean.merge(restaurants, on="place_id", how="left")

# %%
def format_google_review(row):
    return {
        "user": row.get("user", {}).get("name") if isinstance(row.get("user"), dict) else None,
        "rating": row.get("rating"),
        "date": row.get("iso_date"),
        "text": row.get("snippet"),
        "original_link": row.get("link"),   # useful to keep
    }

# %%
grouped = []

for place_id, group in df_clean.groupby("place_id"):
    restaurant_name = group["restaurant"].iloc[0]

    reviews_list = [
        format_google_review(row)
        for _, row in group.iterrows()
    ]

    grouped.append({
        "restaurant": restaurant_name,
        "place_id": place_id,
        "reviews": reviews_list
    })

# %%
import json

output_path = "data/google-data/google-reviews/final/chc_google_reviews.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(grouped, f, ensure_ascii=False, indent=4)

output_path
# Out:
# 'data/google-data/google-reviews/final/chc_google_reviews.json'
